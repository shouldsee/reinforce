# %% [markdown]
# ##### lst = [1,2,3];
# lst.index(1)

# %%
import gym
import numpy as np
import tensorflow as tf
from keras import backend as K
from keras.models import Sequential,load_model
from keras.layers import Dense, Reshape, Flatten
from keras.optimizers import Adam
from keras.layers.convolutional import Convolution2D
from AgentUtil import *

if __name__ == "__main__":
    env = gym.make("Pong-v0")
    state = env.reset()
    prev_x = None
    score = 0
    episode = 0

    state_size = 80 * 80
    action_size = env.action_space.n
    agent = PGAgent(state_size, action_size)
    
agent.summary();
# Out:
# Using TensorFlow backend.
# [2017-06-19 11:28:28,961] Making new env: Pong-v0
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_1 (Reshape)          (None, 80, 80, 1)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 27, 27, 25)        925
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 27, 27, 5)         4505
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 27, 27, 5)         905
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 27, 27, 5)         905
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3645)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 21876
# =================================================================
# Total params: 29,116
# Trainable params: 29,116
# Non-trainable params: 0
# _________________________________________________________________
# AgentUtil.py:27: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(25, (6, 6), kernel_initializer="he_uniform", activation="relu", padding="same", strides=(3, 3))`
#   activation='relu', init='he_uniform'))
# AgentUtil.py:29: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(5, (6, 6), kernel_initializer="he_uniform", activation="relu", padding="same", strides=(1, 1))`
#   activation='relu', init='he_uniform'))
# AgentUtil.py:31: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(5, (6, 6), kernel_initializer="he_uniform", activation="relu", padding="same", strides=(1, 1))`
#   activation='relu', init='he_uniform'))
# AgentUtil.py:33: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(5, (6, 6), kernel_initializer="he_uniform", activation="relu", padding="same", strides=(1, 1))`
#   activation='relu', init='he_uniform'))

# %%
import gym
import numpy as np
import tensorflow as tf
from keras import backend as K
from keras.models import Sequential,load_model
from keras.layers import Dense, Reshape, Flatten
from keras.optimizers import Adam
from keras.layers.convolutional import Convolution2D

class PGAgent:
    def __init__(self, state_size, action_size,AgentName = 'tst'):
#         AgentName = 'pong_minimal-s5L1b-tst'
        self.AgentFile = 'Models/%s.h5'%AgentName;
        self.LogName = 'Models/%s.log'%AgentName;
        self.state_size = state_size
        self.action_size = action_size
        self.gamma = 0.99
        self.learning_rate = 0.001
        self.states = []
        self.gradients = []
        self.rewards = []
        self.probs = []
        self.model = self._build_model()
        self.summary = self.model.summary;

    def _build_model(self):
        model = Sequential()
        model.add(Reshape((80, 80, 1), input_shape=(self.state_size,)))
        model.add(Convolution2D(25, (6, 6), subsample=(3, 3), border_mode='same',
                                activation='relu', init='he_uniform'))
        model.add(Convolution2D(5, (6, 6), subsample=(1, 1), border_mode='same',
                                activation='relu', init='he_uniform'))
        model.add(Convolution2D(5, (6, 6), subsample=(1, 1), border_mode='same',
                                activation='relu', init='he_uniform'))
        model.add(Convolution2D(5, (6, 6), subsample=(1, 1), border_mode='same',
                                activation='relu', init='he_uniform'))
        model.add(Flatten())
#         model.add(Dense(20, activation='relu', init='he_uniform'))
#         model.add(Dense(20, activation='relu', init='he_uniform'))
        model.add(Dense(self.action_size, activation='softmax'))
        opt = Adam(lr=self.learning_rate)
        model.compile(loss='categorical_crossentropy', optimizer=opt)
        return model

    def remember(self, state, action, prob, reward):
        y = np.zeros([self.action_size])
        y[action] = 1
        self.gradients.append(np.array(y).astype('float32') - prob)
        self.states.append(state)
        self.rewards.append(reward)

    def act(self, state):
        # state = state.reshape([1, state.shape[0]])
        aprob = self.model.predict(state, batch_size=1).flatten()
        self.probs.append(aprob)
        prob = aprob / np.sum(aprob)
        action = np.random.choice(self.action_size, 1, p=prob)[0]
        return action, prob

    def discount_rewards(self, rewards):
        discounted_rewards = np.zeros_like(rewards)
        running_add = 0
        for t in reversed(range(0, rewards.size)):
            if rewards[t] != 0:
                running_add = 0
            running_add = running_add * self.gamma + rewards[t]
            discounted_rewards[t] = running_add
        return discounted_rewards

    def train(self,rewards,batch_size = 2000,verbose = 0):
        gradients = np.vstack(self.gradients)
        # rewards = np.vstack(self.rewards)
        # rewards = self.discount_rewards(rewards)
        rewards = (rewards - np.mean(rewards,keepdims=1)) / np.std(rewards)
        gradients *= rewards
        X = np.squeeze(np.vstack([self.states]))
        Y = self.probs + self.learning_rate * np.squeeze(np.vstack([gradients]))
#         self.model.train_on_batch(X, Y)
        X = np.expand_dims(X,axis = 1)
        Y = np.expand_dims(Y,axis = 1)
    
        gen = ((X[i],Y[i]) for i in range(len(X)));
#         print(len(X))
        bmax = max(X.shape[0]//batch_size,1)
#         print(gen)
#         print(bmax)
        self.model.fit_generator(gen,steps_per_epoch = bmax, epochs = 1,verbose = verbose)
        self.states, self.probs, self.gradients, self.rewards = [], [], [], []

    def load(self, fname=None):
        if not fname:
            fname = self.AgentFile;
        global episode
        self.model = load_model(fname);
        self.summary = self.model.summary;
        
    def readlog(self, LogName):
#         LogName = self.LogName;
        with open(LogName,'rb') as f:
                first = f.readline()      # Read the first line.
                f.seek(-2, 2)             # Jump to the second last byte.
                while f.read(1) != b"\n": # Until EOL is found...
                    f.seek(-2, 1)         # ...jump back the read byte plus one more.
                last = f.readline() 
                lst = last.split('\t');
                eind = lst.index('Episode')+1;
                self.episode = int(lst[eind]);

    def save(self, fname=None):
        if not fname:
            fname = self.AgentFile;
        self.model.save(fname);

def preprocess(I):
    I = I[35:195]
    I = I[::2, ::2, 0]
    I[I == 144] = 0
    I[I == 109] = 0
    I[I != 0] = 1
    return I.astype(np.float).ravel()

# agent.summary();

# %%
if __name__ == "__main__":
    env = gym.make("Pong-v0")
    state = env.reset()
    prev_x = None
    score = 0
    episode = 0

    state_size = 80 * 80
    action_size = env.action_space.n
    agent = PGAgent(state_size, action_size,AgentName='pong_minimal-s5L0')
#     agent.summary();

AgentName = 'pong_minimal-s5L1b-tst'
AgentFile = 'Models/%s.h5'%AgentName;
LogName = 'Models/%s.log'%AgentName;
# LogFile = open(LogName,'a');
resume = 1;
render = 0;
usegpu = 0;
agent.load()
# agent.summary()
# agent.readlog(LogName)
# print(agent.episode)
# Out:
# [2017-06-19 11:30:38,919] Making new env: Pong-v0
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:31: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(25, (6, 6), kernel_initializer="he_uniform", activation="relu", padding="same", strides=(3, 3))`
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:33: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(5, (6, 6), kernel_initializer="he_uniform", activation="relu", padding="same", strides=(1, 1))`
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:35: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(5, (6, 6), kernel_initializer="he_uniform", activation="relu", padding="same", strides=(1, 1))`
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:37: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(5, (6, 6), kernel_initializer="he_uniform", activation="relu", padding="same", strides=(1, 1))`
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_4 (Reshape)          (None, 80, 80, 1)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 27, 27, 25)        925
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 18225)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 6)                 109356
# =================================================================
# Total params: 110,281
# Trainable params: 110,281
# Non-trainable params: 0
# _________________________________________________________________

# %%
def main():
    if __name__ == "__main__":
        if not usegpu:
            sess = tf.Session(config=tf.ConfigProto(log_device_placement=True, device_count = {'GPU': 0}))
            K.set_session(sess)
        env = gym.make("Pong-v0")
        state = env.reset()
        prev_x = None
        score = 0
        episode = 0

        state_size = 80 * 80
        action_size = env.action_space.n
        agent = PGAgent(state_size, action_size)
    #     agent.summary();


        if resume:
            agent.load(AgentFile);
            agent.readlog(LogName);
            episode = agent.episode;
        while episode > -1:
#         while episode < 5:
            if render:
                    env.render()

            cur_x = preprocess(state)
            x = cur_x - prev_x if prev_x is not None else np.zeros(state_size)
            prev_x = cur_x

            action, prob = agent.act(np.expand_dims(x,1).T)
            state, reward, done, info = env.step(action)
            score += reward
            agent.remember(x, action, prob, reward)

            if done:
                episode += 1
                rewards = np.vstack(agent.rewards)
                rewards = agent.discount_rewards(rewards)
                grads = np.vstack(agent.gradients);
        #             pca.fit (grads )
        #             lvar = pca.explained_variance_ratio_[0];
                lvar = 0;
                var_lst = np.var(grads,axis = 0);
                L1_lst = abs(np.mean(grads,axis = 0));
                L1_norm = np.mean(L1_lst)
                all_var = np.mean(var_lst);            

                agent.train(rewards)
                msg = '%s\t%d\t%s\t%f\t%s\t%f\t%s\t%f\t%s\t%f' % ('Episode',episode,'Score', score,'largest_variance',lvar,'all_var',all_var,'L1_norm',L1_norm);
                print(msg);
                with open(LogName,'a+') as LogFile:
                    LogFile.write(msg+'\n');

                score = 0
                state = env.reset()
                prev_x = None
                if episode > 1 and episode % 10 == 0:
                    agent.save(AgentFile)

# %%
# %load_ext line_profiler

# %lprun -f main main() 
# > 'log/output.html'
# Out:
# [2017-06-19 09:51:52,778] Making new env: Pong-v0
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:29: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(25, (6, 6), kernel_initializer="he_uniform", activation="relu", padding="same", strides=(3, 3))`
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:31: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(5, (6, 6), kernel_initializer="he_uniform", activation="relu", padding="same", strides=(1, 1))`
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:33: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(5, (6, 6), kernel_initializer="he_uniform", activation="relu", padding="same", strides=(1, 1))`
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:35: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(5, (6, 6), kernel_initializer="he_uniform", activation="relu", padding="same", strides=(1, 1))`
# Episode	2010	Score	-21.000000	largest_variance	0.000000	all_var	0.006163	L1_norm	0.001761
# Episode	2011	Score	-20.000000	largest_variance	0.000000	all_var	0.007566	L1_norm	0.001126
# Episode	2012	Score	-20.000000	largest_variance	0.000000	all_var	0.007770	L1_norm	0.001467
# Episode	2013	Score	-21.000000	largest_variance	0.000000	all_var	0.007657	L1_norm	0.001171
# Episode	2014	Score	-20.000000	largest_variance	0.000000	all_var	0.006361	L1_norm	0.000750
# Episode	2015	Score	-17.000000	largest_variance	0.000000	all_var	0.005574	L1_norm	0.000967
# Episode	2016	Score	-19.000000	largest_variance	0.000000	all_var	0.004391	L1_norm	0.001725
# Episode	2017	Score	-20.000000	largest_variance	0.000000	all_var	0.006506	L1_norm	0.002477
# Episode	2018	Score	-19.000000	largest_variance	0.000000	all_var	0.006490	L1_norm	0.001987
# Episode	2019	Score	-21.000000	largest_variance	0.000000	all_var	0.007763	L1_norm	0.002669
# Episode	2020	Score	-20.000000	largest_variance	0.000000	all_var	0.007257	L1_norm	0.002309
# Episode	2021	Score	-21.000000	largest_variance	0.000000	all_var	0.006367	L1_norm	0.001672
# Episode	2022	Score	-21.000000	largest_variance	0.000000	all_var	0.005533	L1_norm	0.001502
# Episode	2023	Score	-20.000000	largest_variance	0.000000	all_var	0.008311	L1_norm	0.001414
# Episode	2024	Score	-21.000000	largest_variance	0.000000	all_var	0.006316	L1_norm	0.001196
# Episode	2025	Score	-21.000000	largest_variance	0.000000	all_var	0.007681	L1_norm	0.000728
# Episode	2026	Score	-21.000000	largest_variance	0.000000	all_var	0.009591	L1_norm	0.002293
# Episode	2027	Score	-21.000000	largest_variance	0.000000	all_var	0.005860	L1_norm	0.002725
# Episode	2028	Score	-21.000000	largest_variance	0.000000	all_var	0.008167	L1_norm	0.001951
# Episode	2029	Score	-20.000000	largest_variance	0.000000	all_var	0.008623	L1_norm	0.001316
# Episode	2030	Score	-21.000000	largest_variance	0.000000	all_var	0.008885	L1_norm	0.002452
# Episode	2031	Score	-21.000000	largest_variance	0.000000	all_var	0.006999	L1_norm	0.001634
# Episode	2032	Score	-21.000000	largest_variance	0.000000	all_var	0.007098	L1_norm	0.001838
# Episode	2033	Score	-21.000000	largest_variance	0.000000	all_var	0.006509	L1_norm	0.002438
# Episode	2034	Score	-21.000000	largest_variance	0.000000	all_var	0.005919	L1_norm	0.000950
# Episode	2035	Score	-20.000000	largest_variance	0.000000	all_var	0.008419	L1_norm	0.001379
# Episode	2036	Score	-19.000000	largest_variance	0.000000	all_var	0.006019	L1_norm	0.002366
# Episode	2037	Score	-20.000000	largest_variance	0.000000	all_var	0.007535	L1_norm	0.000811
# Episode	2038	Score	-21.000000	largest_variance	0.000000	all_var	0.008098	L1_norm	0.002584
# Episode	2039	Score	-20.000000	largest_variance	0.000000	all_var	0.009112	L1_norm	0.001757
# Episode	2040	Score	-20.000000	largest_variance	0.000000	all_var	0.006079	L1_norm	0.001906
# Episode	2041	Score	-20.000000	largest_variance	0.000000	all_var	0.008188	L1_norm	0.002135
# Episode	2042	Score	-21.000000	largest_variance	0.000000	all_var	0.005980	L1_norm	0.001281
# Episode	2043	Score	-19.000000	largest_variance	0.000000	all_var	0.006155	L1_norm	0.001113
# Episode	2044	Score	-21.000000	largest_variance	0.000000	all_var	0.006758	L1_norm	0.001848
# Episode	2045	Score	-21.000000	largest_variance	0.000000	all_var	0.007165	L1_norm	0.001966
# Episode	2046	Score	-19.000000	largest_variance	0.000000	all_var	0.007520	L1_norm	0.001570
# *** KeyboardInterrupt exception caught in code being profiled.

# %%
#         if render:
#                 env.render()

#         cur_x = preprocess(state)
#         x = cur_x - prev_x if prev_x is not None else np.zeros(state_size)
#         prev_x = cur_x

#         action, prob = agent.act(np.expand_dims(x,1).T)
#         state, reward, done, info = env.step(action)
#         score += reward
#         agent.remember(x, action, prob, reward)

#         if done:
#             episode += 1
#             rewards = np.vstack(agent.rewards)
#             rewards = agent.discount_rewards(rewards)
#             grads = np.vstack(agent.gradients);
#     #             pca.fit (grads )
#     #             lvar = pca.explained_variance_ratio_[0];
#             lvar = 0;
#             var_lst = np.var(grads,axis = 0);
#             L1_lst = abs(np.mean(grads,axis = 0));
#             L1_norm = np.mean(L1_lst)
#             all_var = np.mean(var_lst);            

#             agent.train(rewards)
#             msg = '%s\t%d\t%s\t%f\t%s\t%f\t%s\t%f\t%s\t%f' % ('Episode',episode,'Score', score,'largest_variance',lvar,'all_var',all_var,'L1_norm',L1_norm);
#             print(msg);
#             with open(LogName,'a+') as LogFile:
#                 LogFile.write(msg+'\n');

#             score = 0
#             state = env.reset()
#             prev_x = None
#             if episode > 1 and episode % 10 == 0:
#                 agent.save(AgentFile)

# %%
# %lprun -f agent.act action, prob = agent.act(np.expand_dims(x,1).T)

# %%
# # len(agent.probs)
# from sklearn.decomposition import PCA
# X = np.vstack(agent.gradients)
# pca = PCA(n_components = 1)
# pca.fit(X)
# print(pca.explained_variance_ratio_)
