# %%
lst = [1,2,3];
lst.index(1)
# Out:
# 0

# %%
import gym
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Reshape, Flatten
from keras.optimizers import Adam
from keras.layers.convolutional import Convolution2D


class PGAgent:
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.gamma = 0.99
        self.learning_rate = 0.001
        self.states = []
        self.gradients = []
        self.rewards = []
        self.probs = []
        self.model = self._build_model()
        self.summary = self.model.summary;

    def _build_model(self):
        model = Sequential()
        model.add(Reshape((80, 80, 1), input_shape=(self.state_size,)))
        model.add(Convolution2D(25, (6, 6), subsample=(3, 3), border_mode='same',
                                activation='relu', init='he_uniform'))
        model.add(Convolution2D(5, (6, 6), subsample=(1, 1), border_mode='same',
                                activation='relu', init='he_uniform'))
        model.add(Flatten())
        model.add(Dense(20, activation='relu', init='he_uniform'))
        model.add(Dense(20, activation='relu', init='he_uniform'))
        model.add(Dense(self.action_size, activation='softmax'))
        opt = Adam(lr=self.learning_rate)
        model.compile(loss='categorical_crossentropy', optimizer=opt)
        return model

    def remember(self, state, action, prob, reward):
        y = np.zeros([self.action_size])
        y[action] = 1
        self.gradients.append(np.array(y).astype('float32') - prob)
        self.states.append(state)
        self.rewards.append(reward)

    def act(self, state):
        # state = state.reshape([1, state.shape[0]])
        aprob = self.model.predict(state, batch_size=1).flatten()
        self.probs.append(aprob)
        prob = aprob / np.sum(aprob)
        action = np.random.choice(self.action_size, 1, p=prob)[0]
        return action, prob

    def discount_rewards(self, rewards):
        discounted_rewards = np.zeros_like(rewards)
        running_add = 0
        for t in reversed(range(0, rewards.size)):
            if rewards[t] != 0:
                running_add = 0
            running_add = running_add * self.gamma + rewards[t]
            discounted_rewards[t] = running_add
        return discounted_rewards

    def train(self,rewards):
        gradients = np.vstack(self.gradients)
        # rewards = np.vstack(self.rewards)
        # rewards = self.discount_rewards(rewards)
        rewards = (rewards - np.mean(rewards,keepdims=1)) / np.std(rewards)
        gradients *= rewards
        X = np.squeeze(np.vstack([self.states]))
        Y = self.probs + self.learning_rate * np.squeeze(np.vstack([gradients]))
        self.model.train_on_batch(X, Y)
        self.states, self.probs, self.gradients, self.rewards = [], [], [], []

    def load(self, name):
        global episode
        self.model.load_weights(name)
    def readlog(self, LogName):
#         LogName = self.LogName;
        with open(LogName,'rb') as f:
                first = f.readline()      # Read the first line.
                f.seek(-2, 2)             # Jump to the second last byte.
                while f.read(1) != b"\n": # Until EOL is found...
                    f.seek(-2, 1)         # ...jump back the read byte plus one more.
                last = f.readline() 
                lst = last.split('\t');
                eind = lst.index('Episode')+1;
                self.episode = int(lst[eind]);

    def save(self, name):
        self.model.save_weights(name)

def preprocess(I):
    I = I[35:195]
    I = I[::2, ::2, 0]
    I[I == 144] = 0
    I[I == 109] = 0
    I[I != 0] = 1
    return I.astype(np.float).ravel()
if __name__ == "__main__":
    env = gym.make("Pong-v0")
    state = env.reset()
    prev_x = None
    score = 0
    episode = 0

    state_size = 80 * 80
    action_size = env.action_space.n
    agent = PGAgent(state_size, action_size)
    
agent.summary();
# Out:
# [2017-06-14 13:17:15,384] Making new env: Pong-v0
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:26: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(25, (6, 6), kernel_initializer="he_uniform", activation="relu", padding="same", strides=(3, 3))`
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:28: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(5, (6, 6), kernel_initializer="he_uniform", activation="relu", padding="same", strides=(1, 1))`
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:30: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(20, kernel_initializer="he_uniform", activation="relu")`
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:31: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(20, kernel_initializer="he_uniform", activation="relu")`
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_4 (Reshape)          (None, 80, 80, 1)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 27, 27, 25)        925
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 27, 27, 5)         4505
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 3645)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 20)                72920
# _________________________________________________________________
# dense_11 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_12 (Dense)             (None, 6)                 126
# =================================================================
# Total params: 78,896
# Trainable params: 78,896
# Non-trainable params: 0
# _________________________________________________________________

# %%
if __name__ == "__main__":
    env = gym.make("Pong-v0")
    state = env.reset()
    prev_x = None
    score = 0
    episode = 0

    state_size = 80 * 80
    action_size = env.action_space.n
    agent = PGAgent(state_size, action_size)
    
agent.summary();
# Out:
# [2017-06-14 13:17:16,023] Making new env: Pong-v0
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_5 (Reshape)          (None, 80, 80, 1)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 27, 27, 25)        925
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 27, 27, 5)         4505
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 3645)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 20)                72920
# _________________________________________________________________
# dense_14 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_15 (Dense)             (None, 6)                 126
# =================================================================
# Total params: 78,896
# Trainable params: 78,896
# Non-trainable params: 0
# _________________________________________________________________
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:26: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(25, (6, 6), kernel_initializer="he_uniform", activation="relu", padding="same", strides=(3, 3))`
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:28: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(5, (6, 6), kernel_initializer="he_uniform", activation="relu", padding="same", strides=(1, 1))`
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:30: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(20, kernel_initializer="he_uniform", activation="relu")`
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:31: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(20, kernel_initializer="he_uniform", activation="relu")`

# %%
if __name__ == "__main__":
    env = gym.make("Pong-v0")
    state = env.reset()
    prev_x = None
    score = 0
    episode = 0

    state_size = 80 * 80
    action_size = env.action_space.n
    agent = PGAgent(state_size, action_size)
#     agent.summary();

AgentName = 'pong_minimal-s4'
AgentFile = 'Models/%s.h5'%AgentName;
LogName = 'Models/%s.log'%AgentName;
# LogFile = open(LogName,'a');
resume = 0;
render = 0;
# agent.readlog(LogName)
# print(agent.episode)
# Out:
# [2017-06-14 13:19:17,380] Making new env: Pong-v0
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:26: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(25, (6, 6), kernel_initializer="he_uniform", activation="relu", padding="same", strides=(3, 3))`
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:28: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(5, (6, 6), kernel_initializer="he_uniform", activation="relu", padding="same", strides=(1, 1))`
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:30: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(20, kernel_initializer="he_uniform", activation="relu")`
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:31: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(20, kernel_initializer="he_uniform", activation="relu")`

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 1)

# %%
if __name__ == "__main__":
    env = gym.make("Pong-v0")
    state = env.reset()
    prev_x = None
    score = 0
    episode = 0

    state_size = 80 * 80
    action_size = env.action_space.n
    agent = PGAgent(state_size, action_size)
#     agent.summary();
    

    if resume:
        agent.load(AgentFile);
        agent.readlog(LogName);
        episode = agent.episode;
    while episode > -1:
        if render:
            env.render()

        cur_x = preprocess(state)
        x = cur_x - prev_x if prev_x is not None else np.zeros(state_size)
        prev_x = cur_x

        action, prob = agent.act(np.expand_dims(x,1).T)
        state, reward, done, info = env.step(action)
        score += reward
        agent.remember(x, action, prob, reward)
        
        if done:
            episode += 1
            rewards = np.vstack(agent.rewards)
            rewards = agent.discount_rewards(rewards)
            grads = np.vstack(agent.gradients);
            pca.fit (grads )
            lvar = pca.explained_variance_ratio_[0];
            all_var = np.sum(np.var(grads,axis = 0));            
            
            agent.train(rewards)
            msg = '%s\t%d\t%s\t%f\t%s\t%f\t%s\t%f' % ('Episode',episode,'Score', score,'largest_variance',lvar,'all_var',all_var);
            print(msg);
            with open(LogName,'a+') as LogFile:
                LogFile.write(msg+'\n');
            
            score = 0
            state = env.reset()
            prev_x = None
            if episode > 1 and episode % 10 == 0:
                agent.save(AgentFile)
# Out:
# [2017-06-14 13:21:25,472] Making new env: Pong-v0
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:26: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(25, (6, 6), kernel_initializer="he_uniform", activation="relu", padding="same", strides=(3, 3))`
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:28: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(5, (6, 6), kernel_initializer="he_uniform", activation="relu", padding="same", strides=(1, 1))`
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:30: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(20, kernel_initializer="he_uniform", activation="relu")`
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:31: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(20, kernel_initializer="he_uniform", activation="relu")`
# Episode	1	Score	-21.000000	largest_variance	0.232122	all_var	0.830286
# Episode	2	Score	-21.000000	largest_variance	0.213971	all_var	0.832963
# Episode	3	Score	-18.000000	largest_variance	0.219262	all_var	0.831578
# Episode	4	Score	-20.000000	largest_variance	0.211644	all_var	0.832035
# Episode	5	Score	-20.000000	largest_variance	0.218808	all_var	0.831956
# Episode	6	Score	-20.000000	largest_variance	0.226158	all_var	0.830954
# Episode	7	Score	-21.000000	largest_variance	0.220775	all_var	0.832399
# Episode	8	Score	-21.000000	largest_variance	0.211851	all_var	0.832975
# Episode	9	Score	-21.000000	largest_variance	0.215066	all_var	0.832979
# Episode	10	Score	-20.000000	largest_variance	0.219646	all_var	0.831507
# Episode	11	Score	-21.000000	largest_variance	0.231161	all_var	0.830269
# Episode	12	Score	-21.000000	largest_variance	0.227481	all_var	0.830752
# Episode	13	Score	-20.000000	largest_variance	0.217290	all_var	0.831939
# Episode	14	Score	-21.000000	largest_variance	0.225498	all_var	0.830535
# Episode	15	Score	-19.000000	largest_variance	0.213367	all_var	0.832313
# Episode	16	Score	-20.000000	largest_variance	0.215500	all_var	0.830746
# Episode	17	Score	-20.000000	largest_variance	0.218061	all_var	0.831354
# Episode	18	Score	-20.000000	largest_variance	0.223013	all_var	0.831920
# Episode	19	Score	-21.000000	largest_variance	0.222077	all_var	0.831065
# Episode	20	Score	-19.000000	largest_variance	0.208033	all_var	0.832145
# Episode	21	Score	-20.000000	largest_variance	0.224047	all_var	0.830870
# Episode	22	Score	-20.000000	largest_variance	0.214166	all_var	0.832444
# Episode	23	Score	-21.000000	largest_variance	0.222666	all_var	0.831147
# Episode	24	Score	-19.000000	largest_variance	0.225062	all_var	0.832293
# Episode	25	Score	-20.000000	largest_variance	0.215296	all_var	0.832038
# Episode	26	Score	-21.000000	largest_variance	0.211662	all_var	0.832197
# Episode	27	Score	-20.000000	largest_variance	0.217211	all_var	0.831137
# Episode	28	Score	-19.000000	largest_variance	0.240140	all_var	0.829713
# Episode	29	Score	-20.000000	largest_variance	0.220840	all_var	0.830215
# Episode	30	Score	-21.000000	largest_variance	0.216830	all_var	0.831492
# Episode	31	Score	-21.000000	largest_variance	0.224399	all_var	0.830013
# Episode	32	Score	-20.000000	largest_variance	0.210525	all_var	0.831388
# Episode	33	Score	-20.000000	largest_variance	0.225529	all_var	0.830997
# Episode	34	Score	-21.000000	largest_variance	0.225846	all_var	0.830427
# Episode	35	Score	-20.000000	largest_variance	0.218325	all_var	0.831096
# Episode	36	Score	-20.000000	largest_variance	0.222887	all_var	0.830472
# Episode	37	Score	-20.000000	largest_variance	0.231174	all_var	0.828945
# Episode	38	Score	-20.000000	largest_variance	0.228647	all_var	0.830476
# Episode	39	Score	-20.000000	largest_variance	0.222909	all_var	0.830926
# Episode	40	Score	-19.000000	largest_variance	0.233885	all_var	0.827107
# Episode	41	Score	-20.000000	largest_variance	0.235998	all_var	0.826458
# Episode	42	Score	-20.000000	largest_variance	0.237450	all_var	0.825555
# Episode	43	Score	-20.000000	largest_variance	0.227295	all_var	0.827736
# Episode	44	Score	-21.000000	largest_variance	0.224755	all_var	0.828830
# Episode	45	Score	-18.000000	largest_variance	0.247615	all_var	0.827056
# Episode	46	Score	-21.000000	largest_variance	0.241116	all_var	0.827654
# Episode	47	Score	-21.000000	largest_variance	0.239206	all_var	0.827335
# Episode	48	Score	-17.000000	largest_variance	0.240286	all_var	0.824543
# Episode	49	Score	-18.000000	largest_variance	0.234975	all_var	0.829416
# Episode	50	Score	-21.000000	largest_variance	0.247836	all_var	0.824046
# Episode	51	Score	-20.000000	largest_variance	0.250185	all_var	0.824176
# Episode	52	Score	-21.000000	largest_variance	0.239694	all_var	0.830376
# Episode	53	Score	-21.000000	largest_variance	0.256414	all_var	0.824631
# Episode	54	Score	-20.000000	largest_variance	0.281334	all_var	0.815731
# Episode	55	Score	-20.000000	largest_variance	0.264678	all_var	0.820803
# Episode	56	Score	-21.000000	largest_variance	0.245537	all_var	0.828332
# Episode	57	Score	-21.000000	largest_variance	0.249051	all_var	0.820089
# Episode	58	Score	-21.000000	largest_variance	0.265202	all_var	0.817751
# Episode	59	Score	-20.000000	largest_variance	0.275092	all_var	0.814963
# Episode	60	Score	-19.000000	largest_variance	0.261411	all_var	0.821007
# Episode	61	Score	-21.000000	largest_variance	0.234490	all_var	0.822772
# Episode	62	Score	-20.000000	largest_variance	0.255817	all_var	0.819924
# Episode	63	Score	-20.000000	largest_variance	0.232692	all_var	0.827858
# Episode	64	Score	-20.000000	largest_variance	0.250506	all_var	0.822161
# Episode	65	Score	-19.000000	largest_variance	0.251900	all_var	0.822264
# Episode	66	Score	-19.000000	largest_variance	0.246365	all_var	0.821293
# Episode	67	Score	-20.000000	largest_variance	0.260583	all_var	0.820845
# Episode	68	Score	-21.000000	largest_variance	0.257168	all_var	0.823369
# Episode	69	Score	-20.000000	largest_variance	0.245245	all_var	0.821587
# Episode	70	Score	-18.000000	largest_variance	0.246975	all_var	0.823833
# Episode	71	Score	-18.000000	largest_variance	0.249660	all_var	0.823294
# Episode	72	Score	-18.000000	largest_variance	0.256329	all_var	0.817067
# Episode	73	Score	-19.000000	largest_variance	0.250836	all_var	0.819471
# Episode	74	Score	-18.000000	largest_variance	0.226518	all_var	0.823293
# Episode	75	Score	-21.000000	largest_variance	0.251550	all_var	0.819861
# Episode	76	Score	-20.000000	largest_variance	0.263064	all_var	0.815793
# Episode	77	Score	-20.000000	largest_variance	0.246476	all_var	0.821615
# Episode	78	Score	-21.000000	largest_variance	0.240411	all_var	0.821143
# Episode	79	Score	-20.000000	largest_variance	0.265974	all_var	0.815912
# Episode	80	Score	-19.000000	largest_variance	0.259282	all_var	0.818775
# Episode	81	Score	-19.000000	largest_variance	0.244728	all_var	0.819594
# Episode	82	Score	-20.000000	largest_variance	0.253688	all_var	0.817010
# Episode	83	Score	-21.000000	largest_variance	0.236330	all_var	0.823644
# Episode	84	Score	-20.000000	largest_variance	0.240214	all_var	0.822751
# Episode	85	Score	-20.000000	largest_variance	0.246129	all_var	0.823392
# Episode	86	Score	-20.000000	largest_variance	0.231067	all_var	0.823594
# Episode	87	Score	-21.000000	largest_variance	0.276664	all_var	0.814305
# Episode	88	Score	-19.000000	largest_variance	0.242404	all_var	0.823558
# Episode	89	Score	-21.000000	largest_variance	0.221035	all_var	0.826733
# Episode	90	Score	-21.000000	largest_variance	0.239048	all_var	0.820535
# Episode	91	Score	-21.000000	largest_variance	0.246210	all_var	0.820884
# Episode	92	Score	-18.000000	largest_variance	0.247290	all_var	0.819645
# Episode	93	Score	-21.000000	largest_variance	0.230900	all_var	0.822233
# Episode	94	Score	-21.000000	largest_variance	0.247911	all_var	0.820392

# %%
pca.explained_variance_ratio_[0]

# %%
# len(agent.probs)
from sklearn.decomposition import PCA
X = np.vstack(agent.gradients)
pca = PCA(n_components = 1)
pca.fit(X)
print(pca.explained_variance_ratio_)
