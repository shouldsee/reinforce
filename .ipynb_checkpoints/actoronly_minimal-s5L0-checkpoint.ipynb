# %% [markdown]
# ##### lst = [1,2,3];
# lst.index(1)

# %%
import gym
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Reshape, Flatten
from keras.optimizers import Adam
from keras.layers.convolutional import Convolution2D


class PGAgent:
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.gamma = 0.99
        self.learning_rate = 0.001
        self.states = []
        self.gradients = []
        self.rewards = []
        self.probs = []
        self.model = self._build_model()
        self.summary = self.model.summary;

    def _build_model(self):
        model = Sequential()
        model.add(Reshape((80, 80, 1), input_shape=(self.state_size,)))
        model.add(Convolution2D(25, (6, 6), subsample=(3, 3), border_mode='same',
                                activation='relu', init='he_uniform'))
#         model.add(Convolution2D(5, (6, 6), subsample=(1, 1), border_mode='same',
#                                 activation='relu', init='he_uniform'))
        model.add(Flatten())
#         model.add(Dense(20, activation='relu', init='he_uniform'))
#         model.add(Dense(20, activation='relu', init='he_uniform'))
        model.add(Dense(self.action_size, activation='softmax'))
        opt = Adam(lr=self.learning_rate)
        model.compile(loss='categorical_crossentropy', optimizer=opt)
        return model

    def remember(self, state, action, prob, reward):
        y = np.zeros([self.action_size])
        y[action] = 1
        self.gradients.append(np.array(y).astype('float32') - prob)
        self.states.append(state)
        self.rewards.append(reward)

    def act(self, state):
        # state = state.reshape([1, state.shape[0]])
        aprob = self.model.predict(state, batch_size=1).flatten()
        self.probs.append(aprob)
        prob = aprob / np.sum(aprob)
        action = np.random.choice(self.action_size, 1, p=prob)[0]
        return action, prob

    def discount_rewards(self, rewards):
        discounted_rewards = np.zeros_like(rewards)
        running_add = 0
        for t in reversed(range(0, rewards.size)):
            if rewards[t] != 0:
                running_add = 0
            running_add = running_add * self.gamma + rewards[t]
            discounted_rewards[t] = running_add
        return discounted_rewards

    def train(self,rewards):
        gradients = np.vstack(self.gradients)
        # rewards = np.vstack(self.rewards)
        # rewards = self.discount_rewards(rewards)
        rewards = (rewards - np.mean(rewards,keepdims=1)) / np.std(rewards)
        gradients *= rewards
        X = np.squeeze(np.vstack([self.states]))
        Y = self.probs + self.learning_rate * np.squeeze(np.vstack([gradients]))
        self.model.train_on_batch(X, Y)
        self.states, self.probs, self.gradients, self.rewards = [], [], [], []

    def load(self, name):
        global episode
        self.model.load_weights(name)
    def readlog(self, LogName):
#         LogName = self.LogName;
        with open(LogName,'rb') as f:
                first = f.readline()      # Read the first line.
                f.seek(-2, 2)             # Jump to the second last byte.
                while f.read(1) != b"\n": # Until EOL is found...
                    f.seek(-2, 1)         # ...jump back the read byte plus one more.
                last = f.readline() 
                lst = last.split('\t');
                eind = lst.index('Episode')+1;
                self.episode = int(lst[eind]);

    def save(self, name):
#         self.model.save_weights(name)
        self.model.save(name);

def preprocess(I):
    I = I[35:195]
    I = I[::2, ::2, 0]
    I[I == 144] = 0
    I[I == 109] = 0
    I[I != 0] = 1
    return I.astype(np.float).ravel()
if __name__ == "__main__":
    env = gym.make("Pong-v0")
    state = env.reset()
    prev_x = None
    score = 0
    episode = 0

    state_size = 80 * 80
    action_size = env.action_space.n
    agent = PGAgent(state_size, action_size)
    
agent.summary();
# Out:
# [2017-06-14 17:33:09,293] Making new env: Pong-v0
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_3 (Reshape)          (None, 80, 80, 1)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 27, 27, 25)        925
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 18225)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 6)                 109356
# =================================================================
# Total params: 110,281
# Trainable params: 110,281
# Non-trainable params: 0
# _________________________________________________________________
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:26: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(25, (6, 6), kernel_initializer="he_uniform", activation="relu", padding="same", strides=(3, 3))`

# %%
if __name__ == "__main__":
    env = gym.make("Pong-v0")
    state = env.reset()
    prev_x = None
    score = 0
    episode = 0

    state_size = 80 * 80
    action_size = env.action_space.n
    agent = PGAgent(state_size, action_size)
    
agent.summary();
# Out:
# [2017-06-14 17:33:09,783] Making new env: Pong-v0
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_4 (Reshape)          (None, 80, 80, 1)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 27, 27, 25)        925
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 18225)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 6)                 109356
# =================================================================
# Total params: 110,281
# Trainable params: 110,281
# Non-trainable params: 0
# _________________________________________________________________
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:26: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(25, (6, 6), kernel_initializer="he_uniform", activation="relu", padding="same", strides=(3, 3))`

# %%
if __name__ == "__main__":
    env = gym.make("Pong-v0")
    state = env.reset()
    prev_x = None
    score = 0
    episode = 0

    state_size = 80 * 80
    action_size = env.action_space.n
    agent = PGAgent(state_size, action_size)
#     agent.summary();

AgentName = 'pong_minimal-s5L0'
AgentFile = 'Models/%s.h5'%AgentName;
LogName = 'Models/%s.log'%AgentName;
# LogFile = open(LogName,'a');
resume = 0;
render = 0;
# agent.readlog(LogName)
# print(agent.episode)
# Out:
# [2017-06-14 17:33:10,283] Making new env: Pong-v0
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:26: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(25, (6, 6), kernel_initializer="he_uniform", activation="relu", padding="same", strides=(3, 3))`

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 1)

# %%
if __name__ == "__main__":
    env = gym.make("Pong-v0")
    state = env.reset()
    prev_x = None
    score = 0
    episode = 0

    state_size = 80 * 80
    action_size = env.action_space.n
    agent = PGAgent(state_size, action_size)
#     agent.summary();
    

    if resume:
        agent.load(AgentFile);
        agent.readlog(LogName);
        episode = agent.episode;
    while episode > -1:
        if render:
            env.render()

        cur_x = preprocess(state)
        x = cur_x - prev_x if prev_x is not None else np.zeros(state_size)
        prev_x = cur_x

        action, prob = agent.act(np.expand_dims(x,1).T)
        state, reward, done, info = env.step(action)
        score += reward
        agent.remember(x, action, prob, reward)
        
        if done:
            episode += 1
            rewards = np.vstack(agent.rewards)
            rewards = agent.discount_rewards(rewards)
            grads = np.vstack(agent.gradients);
            pca.fit (grads )
            lvar = pca.explained_variance_ratio_[0];
            var_lst = np.var(grads,axis = 0);
            L1_lst = abs(np.mean(grads,axis = 0));
            L1_norm = np.mean(L1_lst)
            all_var = np.mean(var_lst);            
            
            agent.train(rewards)
            msg = '%s\t%d\t%s\t%f\t%s\t%f\t%s\t%f\t%s\t%f' % ('Episode',episode,'Score', score,'largest_variance',lvar,'all_var',all_var,'L1_norm',L1_norm);
            print(msg);
            with open(LogName,'a+') as LogFile:
                LogFile.write(msg+'\n');
            
            score = 0
            state = env.reset()
            prev_x = None
#             if episode > 1 and episode % 10 == 0:
            agent.save(AgentFile)
# Out:
# [2017-06-14 17:33:11,322] Making new env: Pong-v0
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:26: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(25, (6, 6), kernel_initializer="he_uniform", activation="relu", padding="same", strides=(3, 3))`
# Episode	1	Score	-21.000000	largest_variance	0.211395	all_var	0.138612	L1_norm	0.003719
# Episode	2	Score	-19.000000	largest_variance	0.219218	all_var	0.138647	L1_norm	0.010320
# Episode	3	Score	-20.000000	largest_variance	0.216865	all_var	0.138692	L1_norm	0.009401
# Episode	4	Score	-20.000000	largest_variance	0.219262	all_var	0.138755	L1_norm	0.007978
# Episode	5	Score	-20.000000	largest_variance	0.212945	all_var	0.138535	L1_norm	0.008891
# Episode	6	Score	-18.000000	largest_variance	0.213330	all_var	0.138494	L1_norm	0.009037
# Episode	7	Score	-21.000000	largest_variance	0.212061	all_var	0.138557	L1_norm	0.007846
# Episode	8	Score	-19.000000	largest_variance	0.218756	all_var	0.138370	L1_norm	0.009271
# Episode	9	Score	-18.000000	largest_variance	0.217394	all_var	0.138542	L1_norm	0.008868
# Episode	10	Score	-21.000000	largest_variance	0.211421	all_var	0.138040	L1_norm	0.004696
# Episode	11	Score	-20.000000	largest_variance	0.203144	all_var	0.137982	L1_norm	0.006613
# Episode	12	Score	-21.000000	largest_variance	0.214529	all_var	0.137643	L1_norm	0.008064
# Episode	13	Score	-21.000000	largest_variance	0.211681	all_var	0.138164	L1_norm	0.007391
# Episode	14	Score	-20.000000	largest_variance	0.224167	all_var	0.137808	L1_norm	0.011014
# Episode	15	Score	-21.000000	largest_variance	0.220513	all_var	0.137929	L1_norm	0.010376
# Episode	16	Score	-21.000000	largest_variance	0.222820	all_var	0.138023	L1_norm	0.005215
# Episode	17	Score	-20.000000	largest_variance	0.222873	all_var	0.137587	L1_norm	0.009529
# Episode	18	Score	-21.000000	largest_variance	0.219026	all_var	0.137838	L1_norm	0.008938
# Episode	19	Score	-20.000000	largest_variance	0.230094	all_var	0.137507	L1_norm	0.008827
# Episode	20	Score	-20.000000	largest_variance	0.223660	all_var	0.137500	L1_norm	0.006329
# Episode	21	Score	-21.000000	largest_variance	0.230649	all_var	0.136636	L1_norm	0.007055
# Episode	22	Score	-21.000000	largest_variance	0.234901	all_var	0.136957	L1_norm	0.010620
# Episode	23	Score	-19.000000	largest_variance	0.225520	all_var	0.137395	L1_norm	0.011022
# Episode	24	Score	-20.000000	largest_variance	0.237005	all_var	0.136556	L1_norm	0.004356
# Episode	25	Score	-20.000000	largest_variance	0.241016	all_var	0.136668	L1_norm	0.009636
# Episode	26	Score	-20.000000	largest_variance	0.251924	all_var	0.136854	L1_norm	0.010855
# Episode	27	Score	-20.000000	largest_variance	0.234150	all_var	0.136265	L1_norm	0.006817
# Episode	28	Score	-19.000000	largest_variance	0.228542	all_var	0.136436	L1_norm	0.010049
# Episode	29	Score	-20.000000	largest_variance	0.249286	all_var	0.136275	L1_norm	0.010536
# Episode	30	Score	-20.000000	largest_variance	0.229650	all_var	0.137489	L1_norm	0.012934
# Episode	31	Score	-20.000000	largest_variance	0.252126	all_var	0.136352	L1_norm	0.008509
# Episode	32	Score	-19.000000	largest_variance	0.246270	all_var	0.137060	L1_norm	0.010112
# Episode	33	Score	-20.000000	largest_variance	0.257213	all_var	0.135267	L1_norm	0.011430
# Episode	34	Score	-20.000000	largest_variance	0.253507	all_var	0.135864	L1_norm	0.007652
# Episode	35	Score	-19.000000	largest_variance	0.250516	all_var	0.135931	L1_norm	0.004950
# Episode	36	Score	-20.000000	largest_variance	0.255887	all_var	0.135709	L1_norm	0.003318
# Episode	37	Score	-21.000000	largest_variance	0.236462	all_var	0.136277	L1_norm	0.014444
# Episode	38	Score	-20.000000	largest_variance	0.258545	all_var	0.135441	L1_norm	0.007417
# Episode	39	Score	-20.000000	largest_variance	0.262801	all_var	0.135827	L1_norm	0.010803
# Episode	40	Score	-19.000000	largest_variance	0.279839	all_var	0.134990	L1_norm	0.010589
# Episode	41	Score	-19.000000	largest_variance	0.289071	all_var	0.134265	L1_norm	0.006540
# Episode	42	Score	-19.000000	largest_variance	0.300478	all_var	0.134000	L1_norm	0.010560
# Episode	43	Score	-21.000000	largest_variance	0.265154	all_var	0.135596	L1_norm	0.017928
# Episode	44	Score	-21.000000	largest_variance	0.291219	all_var	0.134701	L1_norm	0.005068
# Episode	45	Score	-16.000000	largest_variance	0.289884	all_var	0.134067	L1_norm	0.012015
# Episode	46	Score	-21.000000	largest_variance	0.308987	all_var	0.132914	L1_norm	0.011053
# Episode	47	Score	-21.000000	largest_variance	0.307098	all_var	0.132830	L1_norm	0.009566
# Episode	48	Score	-19.000000	largest_variance	0.310180	all_var	0.131984	L1_norm	0.001771
# Episode	49	Score	-19.000000	largest_variance	0.304383	all_var	0.132550	L1_norm	0.011863
# Episode	50	Score	-20.000000	largest_variance	0.326827	all_var	0.130534	L1_norm	0.013659
# Episode	51	Score	-19.000000	largest_variance	0.315673	all_var	0.131053	L1_norm	0.007737
# Episode	52	Score	-20.000000	largest_variance	0.349532	all_var	0.129143	L1_norm	0.005233
# Episode	53	Score	-19.000000	largest_variance	0.344683	all_var	0.129604	L1_norm	0.004861
# Episode	54	Score	-20.000000	largest_variance	0.369003	all_var	0.127124	L1_norm	0.012029
# Episode	55	Score	-20.000000	largest_variance	0.374538	all_var	0.126225	L1_norm	0.007025
# Episode	56	Score	-21.000000	largest_variance	0.398848	all_var	0.124653	L1_norm	0.006747
# Episode	57	Score	-20.000000	largest_variance	0.436899	all_var	0.121405	L1_norm	0.008606
# Episode	58	Score	-19.000000	largest_variance	0.476973	all_var	0.117947	L1_norm	0.013827
# Episode	59	Score	-15.000000	largest_variance	0.465646	all_var	0.117970	L1_norm	0.005560
# Episode	60	Score	-21.000000	largest_variance	0.476638	all_var	0.118976	L1_norm	0.006433
# Episode	61	Score	-21.000000	largest_variance	0.487724	all_var	0.115928	L1_norm	0.010286
# Episode	62	Score	-21.000000	largest_variance	0.515294	all_var	0.113284	L1_norm	0.006359
# Episode	63	Score	-19.000000	largest_variance	0.532165	all_var	0.111005	L1_norm	0.005048
# Episode	64	Score	-19.000000	largest_variance	0.547467	all_var	0.111184	L1_norm	0.004488
# Episode	65	Score	-19.000000	largest_variance	0.554821	all_var	0.109657	L1_norm	0.003090
# Episode	66	Score	-20.000000	largest_variance	0.546284	all_var	0.110876	L1_norm	0.004215
# Episode	67	Score	-18.000000	largest_variance	0.535578	all_var	0.111023	L1_norm	0.005278
# Episode	68	Score	-20.000000	largest_variance	0.507865	all_var	0.112899	L1_norm	0.008876
# Episode	69	Score	-21.000000	largest_variance	0.520601	all_var	0.113153	L1_norm	0.005709
# Episode	70	Score	-20.000000	largest_variance	0.552719	all_var	0.107451	L1_norm	0.010051
# Episode	71	Score	-19.000000	largest_variance	0.521754	all_var	0.110588	L1_norm	0.007218
# Episode	72	Score	-21.000000	largest_variance	0.521410	all_var	0.112848	L1_norm	0.007572
# Episode	73	Score	-18.000000	largest_variance	0.568070	all_var	0.107700	L1_norm	0.004087
# Episode	74	Score	-20.000000	largest_variance	0.561456	all_var	0.105375	L1_norm	0.007238
# Episode	75	Score	-19.000000	largest_variance	0.596783	all_var	0.104828	L1_norm	0.010745
# Episode	76	Score	-19.000000	largest_variance	0.605928	all_var	0.102429	L1_norm	0.008037
# Episode	77	Score	-20.000000	largest_variance	0.580540	all_var	0.104124	L1_norm	0.009624
# Episode	78	Score	-20.000000	largest_variance	0.610883	all_var	0.102319	L1_norm	0.007608
# Episode	79	Score	-20.000000	largest_variance	0.633941	all_var	0.100205	L1_norm	0.004278
# Episode	80	Score	-20.000000	largest_variance	0.620641	all_var	0.099620	L1_norm	0.007267
# Episode	81	Score	-21.000000	largest_variance	0.663653	all_var	0.096519	L1_norm	0.002530
# Episode	82	Score	-18.000000	largest_variance	0.671090	all_var	0.096716	L1_norm	0.007057
# Episode	83	Score	-17.000000	largest_variance	0.718721	all_var	0.092845	L1_norm	0.005182
# Episode	84	Score	-18.000000	largest_variance	0.721418	all_var	0.091846	L1_norm	0.002058
# Episode	85	Score	-19.000000	largest_variance	0.727136	all_var	0.092179	L1_norm	0.004364
# Episode	86	Score	-18.000000	largest_variance	0.742771	all_var	0.088804	L1_norm	0.001595
# Episode	87	Score	-19.000000	largest_variance	0.734358	all_var	0.087392	L1_norm	0.003399
# Episode	88	Score	-20.000000	largest_variance	0.734664	all_var	0.087047	L1_norm	0.000973
# Episode	89	Score	-19.000000	largest_variance	0.726031	all_var	0.089599	L1_norm	0.002427
# Episode	90	Score	-18.000000	largest_variance	0.741126	all_var	0.087823	L1_norm	0.006862
# Episode	91	Score	-18.000000	largest_variance	0.749335	all_var	0.089396	L1_norm	0.003552
# Episode	92	Score	-16.000000	largest_variance	0.712049	all_var	0.091051	L1_norm	0.004904
# Episode	93	Score	-21.000000	largest_variance	0.737593	all_var	0.088844	L1_norm	0.005781
# Episode	94	Score	-18.000000	largest_variance	0.718240	all_var	0.091016	L1_norm	0.004529
# Episode	95	Score	-18.000000	largest_variance	0.668732	all_var	0.094762	L1_norm	0.008663
# Episode	96	Score	-19.000000	largest_variance	0.650312	all_var	0.093523	L1_norm	0.009241
# Episode	97	Score	-20.000000	largest_variance	0.643533	all_var	0.097510	L1_norm	0.005211
# Episode	98	Score	-18.000000	largest_variance	0.629016	all_var	0.095885	L1_norm	0.005860
# Episode	99	Score	-19.000000	largest_variance	0.597424	all_var	0.096916	L1_norm	0.004625
# Episode	100	Score	-17.000000	largest_variance	0.583680	all_var	0.101080	L1_norm	0.003392
# Episode	101	Score	-17.000000	largest_variance	0.577487	all_var	0.100026	L1_norm	0.004165

# %%
pca.explained_variance_ratio_[0]

# %%
# len(agent.probs)
from sklearn.decomposition import PCA
X = np.vstack(agent.gradients)
pca = PCA(n_components = 1)
pca.fit(X)
print(pca.explained_variance_ratio_)
