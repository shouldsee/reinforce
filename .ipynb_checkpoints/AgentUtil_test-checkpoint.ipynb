# %% [markdown]
# ##### lst = [1,2,3];
# lst.index(1)

# %%
import gym
import numpy as np
import tensorflow as tf
from keras import backend as K
from keras.models import Sequential,load_model
from keras.layers import Dense, Reshape, Flatten
from keras.optimizers import Adam
from keras.layers.convolutional import Convolution2D
from AgentUtil import *

if __name__ == "__main__":
    env = gym.make("Pong-v0")
    state = env.reset()
    prev_x = None
    score = 0
    episode = 0

    state_size = 80 * 80
    action_size = env.action_space.n
    agent = PGAgent(state_size, action_size)
    
agent.summary();
# Out:
# Using TensorFlow backend.
# [2017-06-20 11:12:16,603] Making new env: Pong-v0
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_1 (Reshape)          (None, 80, 80, 1)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 27, 27, 25)        925
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 27, 27, 5)         4505
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 27, 27, 5)         905
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 27, 27, 5)         905
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3645)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 21876
# =================================================================
# Total params: 29,116
# Trainable params: 29,116
# Non-trainable params: 0
# _________________________________________________________________
# AgentUtil.py:40: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(25, (6, 6), kernel_initializer="he_uniform", activation="relu", padding="same", strides=(3, 3))`
#   activation='relu', init='he_uniform'))
# AgentUtil.py:42: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(5, (6, 6), kernel_initializer="he_uniform", activation="relu", padding="same", strides=(1, 1))`
#   activation='relu', init='he_uniform'))
# AgentUtil.py:44: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(5, (6, 6), kernel_initializer="he_uniform", activation="relu", padding="same", strides=(1, 1))`
#   activation='relu', init='he_uniform'))
# AgentUtil.py:46: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(5, (6, 6), kernel_initializer="he_uniform", activation="relu", padding="same", strides=(1, 1))`
#   activation='relu', init='he_uniform'))

# %%
print(str('\n'))

# %%
import gym
import numpy as np
import tensorflow as tf
from keras import backend as K
from keras.models import Sequential,load_model
from keras.layers import Dense, Reshape, Flatten
from keras.optimizers import Adam
from keras.layers.convolutional import Convolution2D

def chunks(l, n):
    """Yield successive n-sized chunks from l."""
    if 1:
        for i in range(0, len(l), n):
    #         print(l.shape)
    #         print(l[i:i + n,:].shape)
    #         print('yield l[%d:%d + %d,:]'%(i,i,n))
            yield l[i:i + n]

class PGAgent:
    def __init__(self, state_size, action_size,AgentName = 'tst'):
#         self.AgentName = 'pong_minimal-s5L1b-tst'
        self.name = AgentName
        self.AgentFile = 'Models/%s.h5'%AgentName;
        self.LogName = 'Models/%s.log'%AgentName;
        self.state_size = state_size
        self.action_size = action_size
        self.gamma = 0.99
        self.learning_rate = 0.001
        self.states = []
        self.gradients = []
        self.rewards = []
        self.probs = []
        self.model = self._build_model()
        self.summary = self.model.summary;

    def _build_model(self):
        model = Sequential()
        model.add(Reshape((80, 80, 1), input_shape=(self.state_size,)))
        model.add(Convolution2D(25, (6, 6), subsample=(3, 3), border_mode='same',
                                activation='relu', init='he_uniform'))
        model.add(Convolution2D(5, (6, 6), subsample=(1, 1), border_mode='same',
                                activation='relu', init='he_uniform'))
        model.add(Convolution2D(5, (6, 6), subsample=(1, 1), border_mode='same',
                                activation='relu', init='he_uniform'))
        model.add(Convolution2D(5, (6, 6), subsample=(1, 1), border_mode='same',
                                activation='relu', init='he_uniform'))
        model.add(Flatten())
#         model.add(Dense(20, activation='relu', init='he_uniform'))
#         model.add(Dense(20, activation='relu', init='he_uniform'))
        model.add(Dense(self.action_size, activation='softmax'))
        opt = Adam(lr=self.learning_rate)
        model.compile(loss='categorical_crossentropy', optimizer=opt)
        return model

    def remember(self, state, action, prob, reward):
        y = np.zeros([self.action_size])
        y[action] = 1
        self.gradients.append(np.array(y).astype('float32') - prob)
        self.states.append(state)
        self.rewards.append(reward)

    def act(self, state):
        # state = state.reshape([1, state.shape[0]])
        aprob = self.model.predict(state, batch_size=1).flatten()
        self.probs.append(aprob)
        prob = aprob / np.sum(aprob)
        action = np.random.choice(self.action_size, 1, p=prob)[0]
        return action, prob

    def discount_rewards(self, rewards):
        discounted_rewards = np.zeros_like(rewards)
        running_add = 0
        for t in reversed(range(0, rewards.size)):
            if rewards[t] != 0:
                running_add = 0
            running_add = running_add * self.gamma + rewards[t]
            discounted_rewards[t] = running_add
        return discounted_rewards

    def train(self,rewards,batch_size = 2000,verbose = 0):
        gradients = np.vstack(self.gradients)
        # rewards = np.vstack(self.rewards)
        # rewards = self.discount_rewards(rewards)
#         rewards = (rewards - np.mean(rewards,keepdims=1)) / np.std(rewards)
#         gradients *= rewards
        
#         X = np.squeeze(np.vstack([self.states]))
#         Y = self.probs + self.learning_rate * np.squeeze(np.vstack([gradients]))
        bmax = max(len(self.gradients)//batch_size,1)

        states = np.vstack(self.states);
        for b in range(bmax):
            idxl = b*batch_size; idxr = (b+1)*batch_size;
            rds = (rewards[idxl:idxr]);
            rds = rds - np.mean(rds);
            gds = gradients[idxl:idxr] * rds;
            Y = self.probs[idxl:idxr] + self.learning_rate * np.squeeze(gds);
            X = states[idxl:idxr];
            self.model.train_on_batch(X, Y);

        #### Method 1, obosolete
#         Xgen = chunks(X,batch_size);
#         Ygen = chunks(Y,batch_size);
#         gen = (x for x in zip(Xgen,Ygen))
# #         gen1 = ((x,y) for x,y in zip(chunks(X,batch_size).next(),chunks(Y,batch_size).next()))
# #         print(gen1.next()[1].shape)
# #         print(chunks(X,batch_size).next().shape)
# #         print()
# #         print(gen)
# #         print(bmax)
#         try:
#             self.model.fit_generator(gen, steps_per_epoch = bmax, epochs = 1,verbose = verbose, max_q_size=1)
#         except StopIteration:
#             pass
        
        ### Method 2
#         bmax = max(X.shape[0]//batch_size,1);
#         for b in range(bmax):
#             self.model.train_on_batch(X[b*batch_size:(b+1)*batch_size,:], Y[b*batch_size:(b+1)*batch_size,:])
# #         self.model.fit(X,Y,  epochs = 1,verbose = verbose)
    
        self.states, self.probs, self.gradients, self.rewards = [], [], [], []

    def load(self, fname=None):
        if not fname:
            fname = self.AgentFile;
        global episode
        self.model = load_model(fname);
        self.summary = self.model.summary;
        
    def readlog(self, LogName=None):
        if not LogName:
            LogName = self.LogName;
        with open(LogName,'rb') as f:
                first = f.readline()      # Read the first line.
                if not first.rstrip('\n'):
#                     print('nothing!')
                    self.episode = 0;
                else:
                    f.seek(-2, 2)             # Jump to the second last byte.
                    while f.read(1) != b"\n": # Until EOL is found...
                        f.seek(-2, 1)         # ...jump back the read byte plus one more.
                    last = f.readline() 
                    lst = last.split('\t');
                    eind = lst.index('Episode')+1;
                    self.episode = int(lst[eind]);

    def save(self, fname=None):
        if not fname:
            fname = self.AgentFile;
        self.model.save(fname);
    def writelog(self, msg, LogName = None):
        if not LogName:
            LogName = self.LogName
        with open(LogName,'a+') as LogFile:
            LogFile.write(msg+'\n');
    def newlog(self):
        open(self.LogName,'w').close();



def main(agent, verbose = 1):
    if __name__ == "__main__":
        env = gym.make("Pong-v0")
        state = env.reset()
        prev_x = None
        score = 0
        episode = 0
    if resume:
        agent.load();
        agent.readlog();
        episode = agent.episode;
    while episode < agent.episode + nb_episode:
        if render:
                env.render()

        cur_x = preprocess(state)
        x = cur_x - prev_x if prev_x is not None else np.zeros(state_size)
        prev_x = cur_x

        action, prob = agent.act(np.expand_dims(x,1).T)
        state, reward, done, info = env.step(action)
        score += reward
        agent.remember(x, action, prob, reward)

        if done:
            episode += 1
            if render: break;
            rewards = np.vstack(agent.rewards)
            rewards = agent.discount_rewards(rewards)
            grads = np.vstack(agent.gradients);
    #             pca.fit (grads )
    #             lvar = pca.explained_variance_ratio_[0];
            lvar = 0;
            var_lst = np.var(grads,axis = 0);
            L1_lst = abs(np.mean(grads,axis = 0));
            L1_norm = np.mean(L1_lst)
            all_var = np.mean(var_lst);            

            agent.train(rewards,batch_size = batch_size,verbose = max(verbose-1,0))
            msg = '%s\t%d\t%s\t%f\t%s\t%f\t%s\t%f\t%s\t%f' % ('Episode',episode,'Score', score,'largest_variance',lvar,'all_var',all_var,'L1_norm',L1_norm);
            if verbose:
                print(msg);
            agent.writelog(msg)

            score = 0
            state = env.reset()
            prev_x = None
            if episode > 1 and episode % 10 == 0 and not render:
                agent.save()
    print('Agent: %s finshed trainning episode %d to %d'%(agent.name, agent.episode,episode))
            
def preprocess(I):
    I = I[35:195]
    I = I[::2, ::2, 0]
    I[I == 144] = 0
    I[I == 109] = 0
    I[I != 0] = 1
    return I.astype(np.float).ravel()


normalise = lambda rewards: (rewards - np.mean(rewards,keepdims=1)) / np.std(rewards)
# agent.summary();

# %%
if __name__ == "__main__":
    env = gym.make("Pong-v0")
    state = env.reset()
    prev_x = None
    score = 0
    episode = 0

    state_size = 80 * 80
    action_size = env.action_space.n
    
#     agent.summary();

AgentName = 'pong_minimal-s5L1b-tst'
# AgentFile = 'Models/%s.h5'%AgentName;
# LogName = 'Models/%s.log'%AgentName;
# LogFile = open(LogName,'a');
resume = 1;
render = 1;
usegpu = 0;
nb_episode = 5;
batch_size = 1000;

K.clear_session()
if not usegpu:
    sess = tf.Session(config=tf.ConfigProto(log_device_placement=True, device_count = {'GPU': 0}))
    K.set_session(sess)
else:
    config = tf.ConfigProto(log_device_placement=True)
    config.gpu_options.per_process_gpu_memory_fraction = 0.65
    config.gpu_options.allow_growth=False
    sess = tf.Session(config=config)
    K.set_session(sess)

agent = PGAgent(state_size, action_size,AgentName=AgentName)

# agent.load()
# agent.summary()
# agent.readlog(LogName)
# print(agent.episode)
# Out:
# [2017-06-20 11:12:17,919] Making new env: Pong-v0
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:40: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(25, (6, 6), kernel_initializer="he_uniform", activation="relu", padding="same", strides=(3, 3))`
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:42: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(5, (6, 6), kernel_initializer="he_uniform", activation="relu", padding="same", strides=(1, 1))`
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:44: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(5, (6, 6), kernel_initializer="he_uniform", activation="relu", padding="same", strides=(1, 1))`
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:46: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(5, (6, 6), kernel_initializer="he_uniform", activation="relu", padding="same", strides=(1, 1))`

# %%
c=np.ones((300,1,300));
c[0:100,:].shape
# Out:
# (100, 1, 300)

# %%
# AgentName = 'pong_minimal-s5L1b-tst'
AgentName = 'pong_minimal-s5L1_i4'

agent = PGAgent(state_size, action_size,AgentName=AgentName)
batch_size = 1500;
nb_episode = 2500;
main(agent,verbose=1) 

# AgentName = 'pong_minimal-s5L0'
# agent = PGAgent(state_size, action_size,AgentName=AgentName)
# main(agent)
# Out:
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:40: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(25, (6, 6), kernel_initializer="he_uniform", activation="relu", padding="same", strides=(3, 3))`
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:42: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(5, (6, 6), kernel_initializer="he_uniform", activation="relu", padding="same", strides=(1, 1))`
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:44: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(5, (6, 6), kernel_initializer="he_uniform", activation="relu", padding="same", strides=(1, 1))`
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:46: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(5, (6, 6), kernel_initializer="he_uniform", activation="relu", padding="same", strides=(1, 1))`
# [2017-06-20 11:12:26,436] Making new env: Pong-v0
# Episode	1	Score	-21.000000	largest_variance	0.000000	all_var	0.138561	L1_norm	0.009769
# Episode	2	Score	-20.000000	largest_variance	0.000000	all_var	0.138627	L1_norm	0.006141
# Episode	3	Score	-20.000000	largest_variance	0.000000	all_var	0.138465	L1_norm	0.013462
# Episode	4	Score	-20.000000	largest_variance	0.000000	all_var	0.138512	L1_norm	0.005131
# Episode	5	Score	-21.000000	largest_variance	0.000000	all_var	0.138513	L1_norm	0.010156
# Episode	6	Score	-19.000000	largest_variance	0.000000	all_var	0.138242	L1_norm	0.008741
# Episode	7	Score	-21.000000	largest_variance	0.000000	all_var	0.138628	L1_norm	0.003546
# Episode	329	Score	-16.000000	largest_variance	0.000000	all_var	0.076072	L1_norm	0.004724
# Episode	330	Score	-17.000000	largest_variance	0.000000	all_var	0.078928	L1_norm	0.003976
# Episode	331	Score	-14.000000	largest_variance	0.000000	all_var	0.072951	L1_norm	0.003091
# Episode	332	Score	-15.000000	largest_variance	0.000000	all_var	0.073614	L1_norm	0.002196
# Episode	333	Score	-17.000000	largest_variance	0.000000	all_var	0.070750	L1_norm	0.004101
# Episode	334	Score	-8.000000	largest_variance	0.000000	all_var	0.068653	L1_norm	0.006190
# Episode	335	Score	-16.000000	largest_variance	0.000000	all_var	0.075797	L1_norm	0.005697
# Episode	336	Score	-19.000000	largest_variance	0.000000	all_var	0.084453	L1_norm	0.003833
# Episode	337	Score	-15.000000	largest_variance	0.000000	all_var	0.083512	L1_norm	0.005063
# Episode	338	Score	-19.000000	largest_variance	0.000000	all_var	0.090759	L1_norm	0.004615
# Episode	339	Score	-18.000000	largest_variance	0.000000	all_var	0.087891	L1_norm	0.008954
# Episode	340	Score	-20.000000	largest_variance	0.000000	all_var	0.089147	L1_norm	0.004899
# Episode	341	Score	-21.000000	largest_variance	0.000000	all_var	0.087049	L1_norm	0.009827
# Episode	342	Score	-18.000000	largest_variance	0.000000	all_var	0.092985	L1_norm	0.008002
# Episode	343	Score	-21.000000	largest_variance	0.000000	all_var	0.087985	L1_norm	0.009580
# Episode	344	Score	-21.000000	largest_variance	0.000000	all_var	0.089945	L1_norm	0.009466
# Episode	345	Score	-21.000000	largest_variance	0.000000	all_var	0.089050	L1_norm	0.006464
# Episode	346	Score	-21.000000	largest_variance	0.000000	all_var	0.089513	L1_norm	0.011141
# Episode	347	Score	-21.000000	largest_variance	0.000000	all_var	0.086633	L1_norm	0.002067
# Episode	348	Score	-21.000000	largest_variance	0.000000	all_var	0.089273	L1_norm	0.003630
# Episode	349	Score	-21.000000	largest_variance	0.000000	all_var	0.086972	L1_norm	0.004127
# Episode	350	Score	-21.000000	largest_variance	0.000000	all_var	0.086337	L1_norm	0.006149
# Episode	351	Score	-21.000000	largest_variance	0.000000	all_var	0.087255	L1_norm	0.010495
# Episode	352	Score	-21.000000	largest_variance	0.000000	all_var	0.089001	L1_norm	0.009930
# Episode	353	Score	-21.000000	largest_variance	0.000000	all_var	0.085530	L1_norm	0.006156
# Episode	354	Score	-21.000000	largest_variance	0.000000	all_var	0.089360	L1_norm	0.004969
# Episode	355	Score	-21.000000	largest_variance	0.000000	all_var	0.083805	L1_norm	0.006718
# Episode	356	Score	-21.000000	largest_variance	0.000000	all_var	0.087370	L1_norm	0.005234
# Episode	357	Score	-21.000000	largest_variance	0.000000	all_var	0.080370	L1_norm	0.008116
# Episode	358	Score	-21.000000	largest_variance	0.000000	all_var	0.086236	L1_norm	0.008671
# Episode	359	Score	-21.000000	largest_variance	0.000000	all_var	0.082685	L1_norm	0.006772
# Episode	360	Score	-21.000000	largest_variance	0.000000	all_var	0.083535	L1_norm	0.008375
# Episode	394	Score	-21.000000	largest_variance	0.000000	all_var	0.086987	L1_norm	0.005178
# Episode	395	Score	-21.000000	largest_variance	0.000000	all_var	0.084673	L1_norm	0.007473
# Episode	396	Score	-21.000000	largest_variance	0.000000	all_var	0.086120	L1_norm	0.010786
# Episode	397	Score	-21.000000	largest_variance	0.000000	all_var	0.078659	L1_norm	0.012504
# Episode	398	Score	-21.000000	largest_variance	0.000000	all_var	0.086706	L1_norm	0.004016
# Episode	399	Score	-21.000000	largest_variance	0.000000	all_var	0.088430	L1_norm	0.004213
# Episode	400	Score	-21.000000	largest_variance	0.000000	all_var	0.089281	L1_norm	0.005909
# Episode	401	Score	-21.000000	largest_variance	0.000000	all_var	0.085019	L1_norm	0.007022
# Episode	402	Score	-21.000000	largest_variance	0.000000	all_var	0.089281	L1_norm	0.007297
# Episode	403	Score	-21.000000	largest_variance	0.000000	all_var	0.084932	L1_norm	0.013423
# Episode	404	Score	-21.000000	largest_variance	0.000000	all_var	0.087822	L1_norm	0.002863
# Episode	405	Score	-21.000000	largest_variance	0.000000	all_var	0.084198	L1_norm	0.004871
# Episode	406	Score	-21.000000	largest_variance	0.000000	all_var	0.088772	L1_norm	0.004328
# Episode	407	Score	-21.000000	largest_variance	0.000000	all_var	0.085910	L1_norm	0.007383
# Episode	408	Score	-21.000000	largest_variance	0.000000	all_var	0.086257	L1_norm	0.005430
# Episode	409	Score	-21.000000	largest_variance	0.000000	all_var	0.086242	L1_norm	0.004073
# Episode	410	Score	-21.000000	largest_variance	0.000000	all_var	0.084817	L1_norm	0.006486
# Episode	411	Score	-21.000000	largest_variance	0.000000	all_var	0.085885	L1_norm	0.005400
# Episode	412	Score	-21.000000	largest_variance	0.000000	all_var	0.087114	L1_norm	0.008280
# Episode	413	Score	-21.000000	largest_variance	0.000000	all_var	0.085118	L1_norm	0.004096
# Episode	414	Score	-21.000000	largest_variance	0.000000	all_var	0.087438	L1_norm	0.006563
# Episode	415	Score	-21.000000	largest_variance	0.000000	all_var	0.085621	L1_norm	0.004713
# Episode	416	Score	-21.000000	largest_variance	0.000000	all_var	0.082675	L1_norm	0.006499
# Episode	417	Score	-21.000000	largest_variance	0.000000	all_var	0.084414	L1_norm	0.007146
# Episode	418	Score	-21.000000	largest_variance	0.000000	all_var	0.084311	L1_norm	0.009351
# Episode	419	Score	-21.000000	largest_variance	0.000000	all_var	0.087085	L1_norm	0.006806
# Episode	420	Score	-21.000000	largest_variance	0.000000	all_var	0.083835	L1_norm	0.002749
# Episode	421	Score	-21.000000	largest_variance	0.000000	all_var	0.087732	L1_norm	0.004982
# Episode	422	Score	-21.000000	largest_variance	0.000000	all_var	0.080891	L1_norm	0.006760
# Episode	423	Score	-21.000000	largest_variance	0.000000	all_var	0.086141	L1_norm	0.007845
# Episode	424	Score	-21.000000	largest_variance	0.000000	all_var	0.083037	L1_norm	0.007005
# Episode	425	Score	-21.000000	largest_variance	0.000000	all_var	0.082760	L1_norm	0.006718
# Episode	426	Score	-21.000000	largest_variance	0.000000	all_var	0.082946	L1_norm	0.005392
# Episode	427	Score	-21.000000	largest_variance	0.000000	all_var	0.085847	L1_norm	0.010199
# Episode	428	Score	-21.000000	largest_variance	0.000000	all_var	0.086017	L1_norm	0.005860
# Episode	429	Score	-21.000000	largest_variance	0.000000	all_var	0.081191	L1_norm	0.004748
# Episode	430	Score	-21.000000	largest_variance	0.000000	all_var	0.080672	L1_norm	0.006456
# Episode	431	Score	-21.000000	largest_variance	0.000000	all_var	0.083009	L1_norm	0.004194
# Episode	432	Score	-21.000000	largest_variance	0.000000	all_var	0.082357	L1_norm	0.004966
# Episode	433	Score	-21.000000	largest_variance	0.000000	all_var	0.079722	L1_norm	0.012585
# Episode	434	Score	-21.000000	largest_variance	0.000000	all_var	0.079607	L1_norm	0.011189
# Episode	435	Score	-21.000000	largest_variance	0.000000	all_var	0.083433	L1_norm	0.005888
# Episode	436	Score	-21.000000	largest_variance	0.000000	all_var	0.080793	L1_norm	0.003035
# Episode	437	Score	-21.000000	largest_variance	0.000000	all_var	0.078566	L1_norm	0.005402
# Episode	438	Score	-21.000000	largest_variance	0.000000	all_var	0.082202	L1_norm	0.009482
# Episode	439	Score	-21.000000	largest_variance	0.000000	all_var	0.082182	L1_norm	0.006577
# Episode	440	Score	-21.000000	largest_variance	0.000000	all_var	0.083293	L1_norm	0.006057
# Episode	441	Score	-21.000000	largest_variance	0.000000	all_var	0.082756	L1_norm	0.004904
# Episode	442	Score	-21.000000	largest_variance	0.000000	all_var	0.081423	L1_norm	0.002884
# Episode	443	Score	-21.000000	largest_variance	0.000000	all_var	0.083463	L1_norm	0.005735
# Episode	444	Score	-21.000000	largest_variance	0.000000	all_var	0.078297	L1_norm	0.009118
# Episode	445	Score	-21.000000	largest_variance	0.000000	all_var	0.078369	L1_norm	0.007997
# Episode	446	Score	-21.000000	largest_variance	0.000000	all_var	0.081085	L1_norm	0.007145
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-d55fbd16f248> in <module>()
#       5 batch_size = 1500;
#       6 nb_episode = 2500;
# ----> 7 main(agent,verbose=1)
#       8
#       9 # AgentName = 'pong_minimal-s5L0'
#
# <ipython-input-3-6b1bbb1ad795> in main(agent, verbose)
#     175                 env.render()
#     176
# --> 177         cur_x = preprocess(state)
#     178         x = cur_x - prev_x if prev_x is not None else np.zeros(state_size)
#     179         prev_x = cur_x
#
# <ipython-input-3-6b1bbb1ad795> in preprocess(I)
#     214     I = I[35:195]
#     215     I = I[::2, ::2, 0]
# --> 216     I[I == 144] = 0
#     217     I[I == 109] = 0
#     218     I[I != 0] = 1
#
# KeyboardInterrupt:

# %%
env.reset()
prev_x,_,_,_ = env.step(2)
curr_x,_,_,_= env.step(2)
x = preprocess(curr_x-prev_x)
agent.act(np.expand_dims(x,0))
# Out:
# (4, array([ 0.00094869,  0.09028251,  0.33583844,  0.03477634,  0.53456658,
#          0.00358745], dtype=float32))

# %%
agent.summary()

# %%
a=chunks([1,5,6,7,8],4)
a1=chunks([1,5,6,7,8],4)

# print(a.__iter__())
dir(a)
# gen = chunks(zipped,batch_size)
# sizeof(a)

# a.__sizeof__()
# print(a.__iter__())
print(a.next())
print(a.next())

print(a.next())

print(a.next())
print(a.next())
print(a.next())
print(a.next())

# a.next()
# c = a[:]
b = (x for x in zip(a.next(),a1.next()))
print(b)
# b

# %%
# AgentName = 'pong_minimal-s5L0'
# agent = PGAgent(state_size, action_size,AgentName=AgentName)
# # agent.newlog()
# nb_episode = 1000;
# main(agent) 


# %load_ext line_profiler
# %lprun -f main main(agent,verbose = 0)

# %%
# AgentName = 'pong_minimal-s5L2'
# agent = PGAgent(state_size, action_size,AgentName=AgentName)
# # agent.newlog()
# nb_episode = 1000;
# main(agent) 


# %load_ext line_profiler
# %lprun -f main main(agent,verbose = 0)

# %%
# AgentName = 'pong_minimal-s5L3'
# agent = PGAgent(state_size, action_size,AgentName=AgentName)
# # agent.newlog()
# nb_episode = 1000;
# main(agent) 


# %load_ext line_profiler
# %lprun -f main main(agent,verbose = 0)

# %%
# ### Build model manually here
# learning_rate = 0.001
# model = Sequential()
# model.add(Reshape((80, 80, 1), input_shape=(state_size,)))
# model.add(Convolution2D(25, (6, 6), subsample=(3, 3), border_mode='same',
#                         activation='relu', init='he_uniform'))
# model.add(Convolution2D(5, (6, 6), subsample=(1, 1), border_mode='same',
#                         activation='relu', init='he_uniform'))
# # model.add(Convolution2D(5, (6, 6), subsample=(1, 1), border_mode='same',
# #                         activation='relu', init='he_uniform'))
# # model.add(Convolution2D(5, (6, 6), subsample=(1, 1), border_mode='same',
# #                         activation='relu', init='he_uniform'))
# model.add(Flatten())
# #         model.add(Dense(20, activation='relu', init='he_uniform'))
# #         model.add(Dense(20, activation='relu', init='he_uniform'))
# model.add(Dense(action_size, activation='softmax'))
# opt = Adam(lr=learning_rate)
# model.compile(loss='categorical_crossentropy', optimizer=opt)

# AgentName = 'pong_minimal-s5L0'
# agent = PGAgent(state_size, action_size,AgentName=AgentName)
# agent.model = model;
# agent.save()

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 1)

# %%
# %load_ext line_profiler

# %lprun -f main main() 
# > 'log/output.html'

# %%
#         if render:
#                 env.render()

#         cur_x = preprocess(state)
#         x = cur_x - prev_x if prev_x is not None else np.zeros(state_size)
#         prev_x = cur_x

#         action, prob = agent.act(np.expand_dims(x,1).T)
#         state, reward, done, info = env.step(action)
#         score += reward
#         agent.remember(x, action, prob, reward)

#         if done:
#             episode += 1
#             rewards = np.vstack(agent.rewards)
#             rewards = agent.discount_rewards(rewards)
#             grads = np.vstack(agent.gradients);
#     #             pca.fit (grads )
#     #             lvar = pca.explained_variance_ratio_[0];
#             lvar = 0;
#             var_lst = np.var(grads,axis = 0);
#             L1_lst = abs(np.mean(grads,axis = 0));
#             L1_norm = np.mean(L1_lst)
#             all_var = np.mean(var_lst);            

#             agent.train(rewards)
#             msg = '%s\t%d\t%s\t%f\t%s\t%f\t%s\t%f\t%s\t%f' % ('Episode',episode,'Score', score,'largest_variance',lvar,'all_var',all_var,'L1_norm',L1_norm);
#             print(msg);
#             with open(LogName,'a+') as LogFile:
#                 LogFile.write(msg+'\n');

#             score = 0
#             state = env.reset()
#             prev_x = None
#             if episode > 1 and episode % 10 == 0:
#                 agent.save(AgentFile)

# %%
# %lprun -f agent.act action, prob = agent.act(np.expand_dims(x,1).T)

# %%
# # len(agent.probs)
# from sklearn.decomposition import PCA
# X = np.vstack(agent.gradients)
# pca = PCA(n_components = 1)
# pca.fit(X)
# print(pca.explained_variance_ratio_)
