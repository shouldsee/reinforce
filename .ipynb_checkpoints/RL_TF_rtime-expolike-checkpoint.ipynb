# %%
""" Trains an agent with (stochastic) Policy Gradients on Pong. Uses OpenAI Gym. """
import numpy as np
import cPickle as pickle
import tensorflow as tf
import gym
from matplotlib import pyplot as plt
# hyperparameters
H = 200 # number of hidden layer neurons
batch_size = 10 # every how many episodes to do a param update?
learning_rate = 1e-4
gamma = 0.99 # discount factor for reward
# gamma = 1-0.
decay_rate = 0.99 # decay factor for RMSProp leaky sum of grad^2
resume = True # resume from previous checkpoint?
# resume = False;
render = False
# render = True
backlen=20;

def sigmoid(x): 
  return 1.0 / (1.0 + np.exp(-x)) # sigmoid "squashing" function to interval [0,1]

def prepro(I):
  """ prepro 210x160x3 uint8 frame into 6400 (80x80) 1D float vector """
  I = I[35:195] # crop
  I = I[::2,::2,0] # downsample by factor of 2
  I[I == 144] = 0 # erase background (background type 1)
  I[I == 109] = 0 # erase background (background type 2)
  I[I != 0] = 1 # everything else (paddles, ball) just set to 1
  return I.astype(np.float).ravel()

def discount_rewards(r):
  """ take 1D float array of rewards and compute discounted reward """
  discounted_r = np.zeros_like(r)
  running_add = 0
  for t in reversed(xrange(0, r.size)):
    if r[t] != 0: running_add = 0 # reset the sum, since this was a game boundary (pong specific!)
    running_add = running_add * gamma + r[t]
    discounted_r[t] = running_add
  return discounted_r

def policy_forward(x):
  h = np.dot(model['W1'], x)
  h[h<0] = 0 # ReLU nonlinearity
  logp = np.dot(model['W2'], h)
  p = sigmoid(logp)
  return p, h # return probability of taking action 2, and hidden state

def policy_backward(eph, epdlogp):
  """ backward pass. (eph is array of intermediate hidden states) """
  dW2 = np.dot(eph.T, epdlogp).ravel()
  dh = np.outer(epdlogp, model['W2'])
  dh[eph <= 0] = 0 # backpro prelu
  dW1 = np.dot(dh.T, epx)
  return {'W1':dW1, 'W2':dW2}
def lookback(lst):
    lst = lst[-backlen:];
#     np.pad(lst,(20-lst.size,), 'constant', constant_values=0);
    if len(lst) != backlen:
        lst = [None]*(backlen-len(lst)) + lst;
    return(lst)

# %%
# discount_rewards(epdlogp)
x.size
# %matplotlib inline
plt.close('all')
fig=plt.figure(figsize=[10,10])
ax1=plt.subplot()
# ax1.plot(time_epr)
# ax1.plot(discounted_epr)
ax1.scatter(abs(time_epr),eptpred)
# ax1.set_xlim([0, 200])
# ax1.set_xlim([800, 1000])
# ax1.set_ylim([-10, 000])


# ax1.imshow(eph[:500,:500].T)
time_epr.size
# tpreds.size
D1
# Out:
# 80

# %%
np.pi
# Out:
# 3.141592653589793

# %%
# model initialization
resume = 1;
# resume = True;
render = False;
render = True;
H=5;
gamma = 0.99;
D1=80;D2=80;

def time_rewards(r):
    """ take 1D float array of rewards and compute discounted reward """
    discounted_r = np.zeros_like(r)
    running_add = 0
    grad = 0;
    for t in reversed(xrange(0, r.size)):
#         grad = grad * gamma + r[t] ;
        if r[t] != 0: 
            running_add = 0 # reset the sum, since this was a game boundary (pong specific!)
            grad = 2 * (r[t] > 0) - 1; 
        running_add = running_add + grad;
        discounted_r[t] = running_add
    return discounted_r

D = 80 * 80 # input dimensionality: 80x80 grid
tf.reset_default_graph()
# if resume:
#     pass

# else:
#     observations = tf.placeholder(tf.float32, [None,D] , name="input_x")
#     W1 = tf.get_variable("W1", shape=[D, H],
#                initializer=tf.contrib.layers.xavier_initializer())
#     b1 = tf.constant(0.1, shape=[1,H]);
#     W2 = tf.get_variable("W2", shape=[H, 1],
#                initializer=tf.contrib.layers.xavier_initializer())
#     b2 = tf.constant(0.1, shape=[1,1]);
xinput = tf.placeholder(tf.float32, name="input_x")
observations = tf.reshape(xinput,[-1,D1,D2,1])
conv1 = tf.layers.conv2d(
  inputs=observations,
  filters=H,
  kernel_size=[5, 5],
  padding="same",
  activation=tf.nn.relu)
dense = tf.layers.dense(inputs=tf.reshape(conv1,[-1, D*H]), units=H, activation=tf.nn.relu)
dropout = dense;
#     logits = tf.layers.dense(inputs=dropout, units=10)
score = tf.layers.dense(inputs=dropout, units=1,activation = tf.nn.relu)
tf.nn.sigmoid(score)

tvars = tf.trainable_variables()
input_y = tf.placeholder(tf.float32,[None,1], name="input_y")
#     advantages = tf.placeholder(tf.float32,name="reward_signal")
rtime = tf.placeholder(tf.float32,name="reward_signal")

#     loglik = tf.log(input_y*(input_y - probability) + (1 - input_y)*(input_y + probability))
# loss = tf.reduce_mean( tf.square(tf.abs(score/rtime) - 1) - tf.sign(score/rtime) ); 
loss = tf.reduce_mean( tf.square(tf.abs(score/rtime) - 1)  );

# %%
newGrads = tf.gradients(loss,tvars)

batchGrad = [];
for i,var in enumerate(tvars):
    exec('Grad%d'%i + ' = tf.placeholder(tf.float32)');
    exec('batchGrad += [Grad%d]'%i)


optimiser = tf.train.RMSPropOptimizer(learning_rate=learning_rate)
#     batchGrad = optimiser.compute_gradients(loss,tvars);
batchGrad = newGrads;
updateGrads = optimiser.apply_gradients(zip(batchGrad,tvars))
init = tf.global_variables_initializer();

env = gym.make("Pong-v0")
observation = env.reset()
prev_x = None # used in computing the difference frame
xs,hs,dlogps,drs = [],[],[],[]
ys=[];byss=[];rss=[];tpreds=[];
running_reward = None
reward_sum = 0
episode_number = 0
# Out:
# [2017-06-03 15:19:15,539] Making new env: Pong-v0

# %%
# xinput.shape
# Out:
# TensorShape(None)

# %%
# all_vars
# tf.get_tensor_by
# Out:
# <function tensorflow.python.ops.variable_scope.get_variable>

# %%
ModelName = 'expolike_RL_pong_RMSprop'
ModelFile = 'Models/'+ModelName+'.ckpt';
render = False;
resume = 1;
batch_size=1;
learning_rate = 1e-2

# ModelName='save.ckpt'
# fname = 
# with tf.Session() as sess:
# gdcmd='grad_dict = {'+','.join(['Grad%d: gradBuffer[%d]'%(i,i) for i,k in enumerate(tvars)])+'}';
while True:
    sess = tf.Session();
#     gradBuffer = [np.zeros_like(v) for v in sess.run(tvars)]
#     grad_buffer = { k : np.zeros_like(v) for k,v in model.iteritems() } # update buffers that add up gradients over a batch
    if resume: 
#         tf.train.import_meta_graph(ModelFile+'.meta')    
        oSaver = tf.train.Saver()
#         oSaver.restore(sess,ModelFile)
#         oSaver = tf.train.import_meta_graph(ModelFile+'.meta')    
        oSaver.restore(sess,tf.train.latest_checkpoint('./Models/'))
    else:
        sess.run(init)
    while True:
        if render: env.render()

        # preprocess the observation, set input to network to be difference image
        cur_x = prepro(observation)
        diff_x = cur_x - prev_x if prev_x is not None else np.zeros(D)
        prev_x = cur_x
        x = np.reshape(diff_x,[1,D1,D2,1]);
#         aprob = sess.run(probability,feed_dict={observations: x})
        aprob = 0.5;
        tpred = sess.run(score,feed_dict={observations: x})    
        action = 2 if np.random.uniform() < aprob else 3 # roll the dice!

        # record various intermediates (needed later for backprop)
        xs.append(x) # observation
        y = 1 if action == 2 else 0 # a "fake label"
        ys.append(y)
        tpreds.append(tpred);

        # step the environment and get new measurements
        observation, reward, done, info = env.step(action)
        reward_sum += reward
        drs.append(reward) # record reward (has to be done after we call step() to get reward for previous action)

        if done: # an episode finished
            episode_number += 1

            # stack together all inputs, hidden states, action gradients, and rewards for this episode
            epx = np.vstack(xs)
            epy = np.vstack(ys);
            epr = np.vstack(drs)
            eptpred=np.vstack(tpreds);
            xs,hs,dlogps,drs,ys,tpreds = [],[],[],[],[],[] # reset array memory
            
#             # compute the discounted reward backwards through time
#             discounted_epr = discount_rewards(epr)
#             # standardize the rewards to be unit normal (helps control the gradient estimator variance)
#             discounted_epr -= np.mean(discounted_epr)
#             discounted_epr /= np.std(discounted_epr)
#             discounted_epr = discount_rewards(epr);
            time_epr=time_rewards(epr);
#            curr_loss = sess.run(loss,feed_dict={xinput: epx, input_y: epy, rtime: time_epr});
            lst =  sess.run([loss,updateGrads],feed_dict={xinput: epx, input_y: epy, rtime: time_epr});
            curr_loss = lst[0];
#             curr_loss = sess.run(loss,feed_dict={xinput: epx, input_y: epy, rtime: time_epr});
            
#             tGrad = sess.run([loss,newGrads,updateGrads],feed_dict={xinput: epx, input_y: epy, rtime: time_epr});
#             for ix,grad in enumerate(tGrad):
#                 gradBuffer[ix] += grad
            
            # perform rmsprop parameter update every batch_size episodes
            if episode_number % batch_size == 0:
                pass
#                 grad_dict={varname:}
#                 exec(gdcmd);
#                 sess.run(updateGrads,feed_dict={Grad0: gradBuffer[0],W2Grad:gradBuffer[1]})
#                 sess.run(updateGrads)
#                 sess.run(updateGrads,feed_dict={newGrads:tGrad})
#                 sess.run(updateGrads,feed_dict={xinput: epx, input_y: epy, rtime: time_epr});
             
                
#                 gradBuffer = [np.zeros_like(v) for v in sess.run(tvars)]
    
            # boring book-keeping
            running_reward = reward_sum if running_reward is None else running_reward * 0.99 + reward_sum * 0.01
            print 'resetting env. episode %d reward total was %f. loss_func: %f' % (episode_number, reward_sum, curr_loss)
            if episode_number % 10  == 9: 
                oSaver = tf.train.Saver()
                oSess = sess
                oSaver.save(oSess, ModelFile) 
#                 pickle.dump(tf, open('save.p', 'wb'))
            reward_sum = 0
            observation = env.reset() # reset env
            prev_x = None

        if reward != 0: # Pong has either +1 or -1 reward exactly when game ends. 
            bys=lookback(ys);
            byss.append(bys);
            rss.append(reward);
            if len(byss)-1 == 100:
                    byss.pop(0);
                    rss.pop(0);

            pass;
    #     print ('ep %d: game finished, reward: %f' % (episode_number, reward)) + ('' if reward == -1 else ' !!!!!!!!')
# Out:
# resetting env. episode 1 reward total was -20.000000. loss_func: 0.998444
# resetting env. episode 2 reward total was -21.000000. loss_func: 0.997124
# resetting env. episode 3 reward total was -21.000000. loss_func: 0.997632
# resetting env. episode 4 reward total was -20.000000. loss_func: 0.998039
# resetting env. episode 5 reward total was -20.000000. loss_func: 0.997171
# resetting env. episode 6 reward total was -21.000000. loss_func: 0.995549
# resetting env. episode 7 reward total was -19.000000. loss_func: 0.995422
# resetting env. episode 8 reward total was -21.000000. loss_func: 0.993222
# resetting env. episode 9 reward total was -19.000000. loss_func: 0.994853
# resetting env. episode 10 reward total was -21.000000. loss_func: 0.992279
# resetting env. episode 11 reward total was -16.000000. loss_func: 0.992655
# resetting env. episode 12 reward total was -21.000000. loss_func: 0.990881
# resetting env. episode 13 reward total was -21.000000. loss_func: 0.983303
# resetting env. episode 14 reward total was -21.000000. loss_func: 0.979719
# resetting env. episode 15 reward total was -21.000000. loss_func: 0.975132
# resetting env. episode 16 reward total was -20.000000. loss_func: 0.970473
# resetting env. episode 17 reward total was -21.000000. loss_func: 0.951808
# resetting env. episode 18 reward total was -19.000000. loss_func: 0.947760
# resetting env. episode 19 reward total was -20.000000. loss_func: 0.932581
# resetting env. episode 20 reward total was -21.000000. loss_func: 0.882160
# resetting env. episode 21 reward total was -20.000000. loss_func: 0.857220
# resetting env. episode 22 reward total was -21.000000. loss_func: 0.816229
# resetting env. episode 23 reward total was -21.000000. loss_func: 0.826919
# resetting env. episode 24 reward total was -21.000000. loss_func: 0.772539
# resetting env. episode 25 reward total was -21.000000. loss_func: 0.795861
# resetting env. episode 26 reward total was -21.000000. loss_func: 0.774538
# resetting env. episode 27 reward total was -21.000000. loss_func: 0.784378
# resetting env. episode 28 reward total was -21.000000. loss_func: 0.765002
# resetting env. episode 29 reward total was -20.000000. loss_func: 0.790354
# resetting env. episode 30 reward total was -21.000000. loss_func: 0.771854
# resetting env. episode 31 reward total was -20.000000. loss_func: 0.810433
# resetting env. episode 32 reward total was -21.000000. loss_func: 0.820017
# resetting env. episode 33 reward total was -19.000000. loss_func: 0.781645
# resetting env. episode 34 reward total was -20.000000. loss_func: 0.797266
# resetting env. episode 35 reward total was -20.000000. loss_func: 0.800042
# resetting env. episode 36 reward total was -21.000000. loss_func: 0.761283
# resetting env. episode 37 reward total was -21.000000. loss_func: 0.792254
# resetting env. episode 38 reward total was -21.000000. loss_func: 0.771466
# resetting env. episode 39 reward total was -21.000000. loss_func: 0.779835
# resetting env. episode 40 reward total was -21.000000. loss_func: 0.781824
# resetting env. episode 41 reward total was -21.000000. loss_func: 0.782829
# resetting env. episode 42 reward total was -21.000000. loss_func: 0.769506
# resetting env. episode 43 reward total was -21.000000. loss_func: 0.799349
# resetting env. episode 44 reward total was -20.000000. loss_func: 0.799314
# resetting env. episode 45 reward total was -21.000000. loss_func: 0.792780
# resetting env. episode 46 reward total was -19.000000. loss_func: 0.798122
# resetting env. episode 47 reward total was -19.000000. loss_func: 0.805175
# resetting env. episode 48 reward total was -21.000000. loss_func: 0.777281
# resetting env. episode 49 reward total was -21.000000. loss_func: 0.778449
# resetting env. episode 50 reward total was -21.000000. loss_func: 0.738078
# resetting env. episode 51 reward total was -21.000000. loss_func: 0.753585
# resetting env. episode 52 reward total was -19.000000. loss_func: 0.811549
# resetting env. episode 53 reward total was -21.000000. loss_func: 0.765021
# resetting env. episode 54 reward total was -21.000000. loss_func: 0.779611
# resetting env. episode 55 reward total was -21.000000. loss_func: 0.793930
# resetting env. episode 56 reward total was -21.000000. loss_func: 0.807218
# resetting env. episode 57 reward total was -19.000000. loss_func: 0.789785
# resetting env. episode 58 reward total was -21.000000. loss_func: 0.764938
# resetting env. episode 59 reward total was -21.000000. loss_func: 0.841184
# resetting env. episode 60 reward total was -21.000000. loss_func: 0.800777
# resetting env. episode 61 reward total was -21.000000. loss_func: 0.805450
# resetting env. episode 62 reward total was -18.000000. loss_func: 0.796173
# resetting env. episode 63 reward total was -21.000000. loss_func: 0.767286
# resetting env. episode 64 reward total was -21.000000. loss_func: 0.811257
# resetting env. episode 65 reward total was -21.000000. loss_func: 0.848005
# resetting env. episode 66 reward total was -21.000000. loss_func: 0.813810
# resetting env. episode 67 reward total was -21.000000. loss_func: 0.782077
# resetting env. episode 68 reward total was -21.000000. loss_func: 0.745856
# resetting env. episode 69 reward total was -21.000000. loss_func: 0.806399
# resetting env. episode 70 reward total was -21.000000. loss_func: 0.724213
# resetting env. episode 71 reward total was -20.000000. loss_func: 0.764993
# resetting env. episode 72 reward total was -20.000000. loss_func: 0.770908
# resetting env. episode 73 reward total was -21.000000. loss_func: 0.755469
# resetting env. episode 74 reward total was -20.000000. loss_func: 0.784310
# resetting env. episode 75 reward total was -20.000000. loss_func: 0.802298
# resetting env. episode 76 reward total was -21.000000. loss_func: 0.786859
# resetting env. episode 77 reward total was -21.000000. loss_func: 0.791266
# resetting env. episode 78 reward total was -20.000000. loss_func: 0.809151
# resetting env. episode 79 reward total was -21.000000. loss_func: 0.792318
# resetting env. episode 80 reward total was -21.000000. loss_func: 0.764051
# resetting env. episode 81 reward total was -20.000000. loss_func: 0.845733
# resetting env. episode 82 reward total was -21.000000. loss_func: 0.765969
# resetting env. episode 83 reward total was -20.000000. loss_func: 0.756891
# resetting env. episode 84 reward total was -21.000000. loss_func: 0.724544
# resetting env. episode 85 reward total was -21.000000. loss_func: 0.723094
# resetting env. episode 86 reward total was -21.000000. loss_func: 0.639380
# resetting env. episode 87 reward total was -20.000000. loss_func: 0.749029
# resetting env. episode 88 reward total was -21.000000. loss_func: 0.688323
# resetting env. episode 89 reward total was -21.000000. loss_func: 0.659666
# resetting env. episode 90 reward total was -21.000000. loss_func: 0.690914
# resetting env. episode 91 reward total was -21.000000. loss_func: 0.851395
# resetting env. episode 92 reward total was -20.000000. loss_func: 0.988890
# resetting env. episode 93 reward total was -20.000000. loss_func: 0.985208
# resetting env. episode 94 reward total was -21.000000. loss_func: 0.985944
# resetting env. episode 95 reward total was -19.000000. loss_func: 0.983254
# resetting env. episode 96 reward total was -21.000000. loss_func: 0.980751
# resetting env. episode 97 reward total was -20.000000. loss_func: 0.979821
# resetting env. episode 98 reward total was -20.000000. loss_func: 0.978069
# resetting env. episode 99 reward total was -20.000000. loss_func: 0.974056
# resetting env. episode 100 reward total was -21.000000. loss_func: 0.969065
# resetting env. episode 101 reward total was -20.000000. loss_func: 0.970830
# resetting env. episode 102 reward total was -21.000000. loss_func: 0.966983
# resetting env. episode 103 reward total was -21.000000. loss_func: 0.967149
# resetting env. episode 104 reward total was -20.000000. loss_func: 0.971735
# resetting env. episode 105 reward total was -20.000000. loss_func: 0.966114
# resetting env. episode 106 reward total was -21.000000. loss_func: 0.960744
# resetting env. episode 107 reward total was -21.000000. loss_func: 0.956913
# resetting env. episode 108 reward total was -21.000000. loss_func: 0.961884
# resetting env. episode 109 reward total was -19.000000. loss_func: 0.966227
# resetting env. episode 110 reward total was -21.000000. loss_func: 0.954954
# resetting env. episode 111 reward total was -21.000000. loss_func: 0.958361
# resetting env. episode 112 reward total was -21.000000. loss_func: 0.956194
# resetting env. episode 113 reward total was -21.000000. loss_func: 0.954056
# resetting env. episode 114 reward total was -21.000000. loss_func: 0.951200
# resetting env. episode 115 reward total was -21.000000. loss_func: 0.955147
# resetting env. episode 116 reward total was -20.000000. loss_func: 0.957193
# resetting env. episode 117 reward total was -20.000000. loss_func: 0.952273
# resetting env. episode 118 reward total was -21.000000. loss_func: 0.943152
# resetting env. episode 119 reward total was -21.000000. loss_func: 0.940862
# resetting env. episode 120 reward total was -21.000000. loss_func: 0.945804
# resetting env. episode 121 reward total was -21.000000. loss_func: 0.944947
# resetting env. episode 122 reward total was -21.000000. loss_func: 0.933443
# resetting env. episode 123 reward total was -20.000000. loss_func: 0.807749
# resetting env. episode 124 reward total was -19.000000. loss_func: 5.424859
# resetting env. episode 125 reward total was -21.000000. loss_func: 0.947957
# resetting env. episode 126 reward total was -20.000000. loss_func: 0.946744
# resetting env. episode 127 reward total was -21.000000. loss_func: 0.946757
# resetting env. episode 128 reward total was -21.000000. loss_func: 0.945546
# resetting env. episode 129 reward total was -21.000000. loss_func: 0.936120
# resetting env. episode 130 reward total was -21.000000. loss_func: 0.911960
# resetting env. episode 131 reward total was -21.000000. loss_func: 0.792828
# resetting env. episode 132 reward total was -19.000000. loss_func: 0.827288
# resetting env. episode 133 reward total was -21.000000. loss_func: 0.798311
# resetting env. episode 134 reward total was -21.000000. loss_func: 0.709419
# resetting env. episode 135 reward total was -21.000000. loss_func: 0.746846
# resetting env. episode 136 reward total was -21.000000. loss_func: 0.715478
# resetting env. episode 137 reward total was -20.000000. loss_func: 0.809860
# resetting env. episode 138 reward total was -21.000000. loss_func: 0.914166
# resetting env. episode 139 reward total was -21.000000. loss_func: 0.765095
# resetting env. episode 140 reward total was -21.000000. loss_func: 0.728221
# resetting env. episode 141 reward total was -21.000000. loss_func: 0.807626
# resetting env. episode 142 reward total was -19.000000. loss_func: 0.713044
# resetting env. episode 143 reward total was -21.000000. loss_func: 0.625094
# resetting env. episode 144 reward total was -20.000000. loss_func: 0.693147
# resetting env. episode 145 reward total was -21.000000. loss_func: 0.731451
# resetting env. episode 146 reward total was -21.000000. loss_func: 0.710033
# resetting env. episode 147 reward total was -20.000000. loss_func: 0.679064
# resetting env. episode 148 reward total was -21.000000. loss_func: 0.609770
# resetting env. episode 149 reward total was -21.000000. loss_func: 0.662432
# resetting env. episode 150 reward total was -21.000000. loss_func: 0.619592
# resetting env. episode 151 reward total was -20.000000. loss_func: 0.695966
# resetting env. episode 152 reward total was -21.000000. loss_func: 0.573768
# resetting env. episode 153 reward total was -21.000000. loss_func: 0.603739
# resetting env. episode 154 reward total was -20.000000. loss_func: 0.562255
# resetting env. episode 155 reward total was -20.000000. loss_func: 0.713282
# resetting env. episode 156 reward total was -21.000000. loss_func: 0.699317
# resetting env. episode 157 reward total was -21.000000. loss_func: 0.711068
# resetting env. episode 158 reward total was -21.000000. loss_func: 0.668386
# resetting env. episode 159 reward total was -21.000000. loss_func: 0.625425
# resetting env. episode 160 reward total was -21.000000. loss_func: 0.578576
# resetting env. episode 161 reward total was -21.000000. loss_func: 0.606864
# resetting env. episode 162 reward total was -19.000000. loss_func: 0.699310
# resetting env. episode 163 reward total was -21.000000. loss_func: 0.564191
# resetting env. episode 164 reward total was -21.000000. loss_func: 0.531074
# resetting env. episode 165 reward total was -21.000000. loss_func: 0.623085
# resetting env. episode 166 reward total was -21.000000. loss_func: 0.736801
# resetting env. episode 167 reward total was -20.000000. loss_func: 0.633723
# resetting env. episode 168 reward total was -20.000000. loss_func: 0.529934
# resetting env. episode 169 reward total was -21.000000. loss_func: 0.523953
# resetting env. episode 170 reward total was -21.000000. loss_func: 0.719851
# resetting env. episode 171 reward total was -20.000000. loss_func: 0.716206
# resetting env. episode 172 reward total was -19.000000. loss_func: 0.698949
# resetting env. episode 173 reward total was -18.000000. loss_func: 0.677106
# resetting env. episode 174 reward total was -21.000000. loss_func: 0.579718
# resetting env. episode 175 reward total was -21.000000. loss_func: 0.548228
# resetting env. episode 176 reward total was -20.000000. loss_func: 0.640564
# resetting env. episode 177 reward total was -20.000000. loss_func: 0.516848
# resetting env. episode 178 reward total was -21.000000. loss_func: 0.535519
# resetting env. episode 179 reward total was -21.000000. loss_func: 0.450917
# resetting env. episode 180 reward total was -20.000000. loss_func: 0.705515
# resetting env. episode 181 reward total was -21.000000. loss_func: 0.646613
# resetting env. episode 182 reward total was -21.000000. loss_func: 0.524523
# resetting env. episode 183 reward total was -18.000000. loss_func: 0.811815
# resetting env. episode 184 reward total was -21.000000. loss_func: 0.648141
# resetting env. episode 185 reward total was -21.000000. loss_func: 0.592760
# resetting env. episode 186 reward total was -20.000000. loss_func: 0.990798
# resetting env. episode 187 reward total was -21.000000. loss_func: 0.728545
# resetting env. episode 188 reward total was -21.000000. loss_func: 0.637008
# resetting env. episode 189 reward total was -21.000000. loss_func: 0.584352
# resetting env. episode 190 reward total was -21.000000. loss_func: 0.490381
# resetting env. episode 191 reward total was -21.000000. loss_func: 0.398152
# resetting env. episode 192 reward total was -20.000000. loss_func: 0.523832
# resetting env. episode 193 reward total was -21.000000. loss_func: 0.434524
# resetting env. episode 194 reward total was -21.000000. loss_func: 0.494223
# resetting env. episode 195 reward total was -21.000000. loss_func: 0.541683
# resetting env. episode 196 reward total was -20.000000. loss_func: 0.516867
# resetting env. episode 197 reward total was -21.000000. loss_func: 0.373923
# resetting env. episode 198 reward total was -21.000000. loss_func: 0.396847
# resetting env. episode 199 reward total was -21.000000. loss_func: 0.618858
# resetting env. episode 200 reward total was -20.000000. loss_func: 0.560984
# resetting env. episode 201 reward total was -19.000000. loss_func: 0.750741
# resetting env. episode 202 reward total was -20.000000. loss_func: 0.484975
# resetting env. episode 203 reward total was -21.000000. loss_func: 0.529503
# resetting env. episode 204 reward total was -21.000000. loss_func: 0.438302
# resetting env. episode 205 reward total was -20.000000. loss_func: 0.489578
# resetting env. episode 206 reward total was -21.000000. loss_func: 0.449360
# resetting env. episode 207 reward total was -21.000000. loss_func: 0.476144
# resetting env. episode 208 reward total was -21.000000. loss_func: 0.379553
# resetting env. episode 209 reward total was -21.000000. loss_func: 0.359726
# resetting env. episode 210 reward total was -18.000000. loss_func: 0.496223
# resetting env. episode 211 reward total was -21.000000. loss_func: 0.341733
# resetting env. episode 212 reward total was -19.000000. loss_func: 0.634850
# resetting env. episode 213 reward total was -21.000000. loss_func: 0.624689
# resetting env. episode 214 reward total was -21.000000. loss_func: 0.392244
# resetting env. episode 215 reward total was -20.000000. loss_func: 0.460313
# resetting env. episode 216 reward total was -21.000000. loss_func: 0.423636
# resetting env. episode 217 reward total was -21.000000. loss_func: 0.336082
# resetting env. episode 218 reward total was -20.000000. loss_func: 0.528658
# resetting env. episode 219 reward total was -21.000000. loss_func: 0.393047
# resetting env. episode 220 reward total was -21.000000. loss_func: 0.446445
# resetting env. episode 221 reward total was -20.000000. loss_func: 0.440839
# resetting env. episode 222 reward total was -21.000000. loss_func: 0.386077
# resetting env. episode 223 reward total was -21.000000. loss_func: 0.433786
# resetting env. episode 224 reward total was -21.000000. loss_func: 0.491309
# resetting env. episode 225 reward total was -21.000000. loss_func: 0.427949
# resetting env. episode 226 reward total was -21.000000. loss_func: 0.385643
# resetting env. episode 227 reward total was -20.000000. loss_func: 0.471101
# resetting env. episode 228 reward total was -21.000000. loss_func: 0.341839
# resetting env. episode 229 reward total was -21.000000. loss_func: 0.339848
# resetting env. episode 230 reward total was -20.000000. loss_func: 0.393492
# resetting env. episode 231 reward total was -21.000000. loss_func: 0.276823
# resetting env. episode 232 reward total was -21.000000. loss_func: 0.443656
# resetting env. episode 233 reward total was -21.000000. loss_func: 0.333342
# resetting env. episode 234 reward total was -21.000000. loss_func: 0.230380
# resetting env. episode 235 reward total was -20.000000. loss_func: 0.634924
# resetting env. episode 236 reward total was -21.000000. loss_func: 0.559752
# resetting env. episode 237 reward total was -21.000000. loss_func: 0.455810
# resetting env. episode 238 reward total was -21.000000. loss_func: 0.257715
# resetting env. episode 239 reward total was -21.000000. loss_func: 0.393570
# resetting env. episode 240 reward total was -20.000000. loss_func: 0.456263
# resetting env. episode 241 reward total was -20.000000. loss_func: 0.417761
# resetting env. episode 242 reward total was -21.000000. loss_func: 0.452189
# resetting env. episode 243 reward total was -20.000000. loss_func: 0.404317
# resetting env. episode 244 reward total was -21.000000. loss_func: 0.325038
# resetting env. episode 245 reward total was -21.000000. loss_func: 0.450097
# resetting env. episode 246 reward total was -20.000000. loss_func: 0.490504
# resetting env. episode 247 reward total was -18.000000. loss_func: 0.822526
# resetting env. episode 248 reward total was -21.000000. loss_func: 0.545125
# resetting env. episode 249 reward total was -21.000000. loss_func: 0.504038
# resetting env. episode 250 reward total was -21.000000. loss_func: 0.470805
# resetting env. episode 251 reward total was -21.000000. loss_func: 0.951155
# resetting env. episode 252 reward total was -21.000000. loss_func: 0.524141
# resetting env. episode 253 reward total was -20.000000. loss_func: 0.525158
# resetting env. episode 254 reward total was -21.000000. loss_func: 0.382492
# resetting env. episode 255 reward total was -20.000000. loss_func: 0.513162
# resetting env. episode 256 reward total was -21.000000. loss_func: 0.390665
# resetting env. episode 257 reward total was -21.000000. loss_func: 0.340260
# resetting env. episode 258 reward total was -21.000000. loss_func: 0.430528
# resetting env. episode 259 reward total was -20.000000. loss_func: 0.415702
# resetting env. episode 260 reward total was -21.000000. loss_func: 0.408451
# resetting env. episode 261 reward total was -20.000000. loss_func: 0.401148
# resetting env. episode 262 reward total was -19.000000. loss_func: 0.389777
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-122-2712f65c029d> in <module>()
#      32 #         aprob = sess.run(probability,feed_dict={observations: x})
#      33         aprob = 0.5;
# ---> 34         tpred = sess.run(score,feed_dict={observations: x})
#      35         action = 2 if np.random.uniform() < aprob else 3 # roll the dice!
#      36
#
# /home/shouldsee/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     776     try:
#     777       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 778                          run_metadata_ptr)
#     779       if run_metadata:
#     780         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/shouldsee/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     967
#     968     # Create a fetch handler to take care of the structure of fetches.
# --> 969     fetch_handler = _FetchHandler(self._graph, fetches, feed_dict_string)
#     970
#     971     # Run request and get response.
#
# /home/shouldsee/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in __init__(self, graph, fetches, feeds)
#     421         self._assert_fetchable(graph, fetch.op)
#     422         self._fetches.append(fetch_name)
# --> 423         self._ops.append(False)
#     424       # Remember the fetch if it is for a tensor handle.
#     425       if (isinstance(fetch, ops.Tensor) and
#
# KeyboardInterrupt:

# %%
# print(time_epr.ravel())
# time_epr
# tpreds
# H
# np.expand_dims(epx,1).shape
# curr_loss = sess.run(loss,feed_dict={xinput: epx, input_y: epy, rtime: time_epr});
# epx.shape
# tf.reshape(epy);
# D*H
# oSaver = tf.train.Saver()
print(sess.run(score,feed_dict={xinput: epx, input_y: epy, rtime: time_epr}))
# oSess = sess
# oSaver.save(oSess, ModelFile)
# Out:
# [[ nan]
#  [ nan]
#  [ nan]
#  ...,
#  [ nan]
#  [ nan]
#  [ nan]]
