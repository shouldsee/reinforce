# %%
lst = [1,2,3];
lst.index(1)
# Out:
# 0

# %%
import gym
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Reshape, Flatten
from keras.optimizers import Adam
from keras.layers.convolutional import Convolution2D


class PGAgent:
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.gamma = 0.99
        self.learning_rate = 0.001
        self.states = []
        self.gradients = []
        self.rewards = []
        self.probs = []
        self.model = self._build_model()
        self.summary = self.model.summary;

    def _build_model(self):
        model = Sequential()
        model.add(Reshape((80, 80, 1), input_shape=(self.state_size,)))
        model.add(Convolution2D(25, (6, 6), subsample=(3, 3), border_mode='same',
                                activation='relu', init='he_uniform'))
        model.add(Convolution2D(5, (6, 6), subsample=(1, 1), border_mode='same',
                                activation='relu', init='he_uniform'))
        model.add(Flatten())
        model.add(Dense(20, activation='relu', init='he_uniform'))
        model.add(Dense(20, activation='relu', init='he_uniform'))
        model.add(Dense(self.action_size, activation='softmax'))
        opt = Adam(lr=self.learning_rate)
        model.compile(loss='categorical_crossentropy', optimizer=opt)
        return model

    def remember(self, state, action, prob, reward):
        y = np.zeros([self.action_size])
        y[action] = 1
        self.gradients.append(np.array(y).astype('float32') - prob)
        self.states.append(state)
        self.rewards.append(reward)

    def act(self, state):
        # state = state.reshape([1, state.shape[0]])
        aprob = self.model.predict(state, batch_size=1).flatten()
        self.probs.append(aprob)
        prob = aprob / np.sum(aprob)
        action = np.random.choice(self.action_size, 1, p=prob)[0]
        return action, prob

    def discount_rewards(self, rewards):
        discounted_rewards = np.zeros_like(rewards)
        running_add = 0
        for t in reversed(range(0, rewards.size)):
            if rewards[t] != 0:
                running_add = 0
            running_add = running_add * self.gamma + rewards[t]
            discounted_rewards[t] = running_add
        return discounted_rewards

    def train(self,rewards):
        gradients = np.vstack(self.gradients)
        # rewards = np.vstack(self.rewards)
        # rewards = self.discount_rewards(rewards)
        rewards = (rewards - np.mean(rewards,keepdims=1)) / np.std(rewards)
        gradients *= rewards
        X = np.squeeze(np.vstack([self.states]))
        Y = self.probs + self.learning_rate * np.squeeze(np.vstack([gradients]))
        self.model.train_on_batch(X, Y)
        self.states, self.probs, self.gradients, self.rewards = [], [], [], []

    def load(self, name):
        global episode
        self.model.load_weights(name)
    def readlog(self, LogName):
#         LogName = self.LogName;
        with open(LogName,'rb') as f:
                first = f.readline()      # Read the first line.
                f.seek(-2, 2)             # Jump to the second last byte.
                while f.read(1) != b"\n": # Until EOL is found...
                    f.seek(-2, 1)         # ...jump back the read byte plus one more.
                last = f.readline() 
                lst = last.split('\t');
                eind = lst.index('Episode')+1;
                self.episode = int(lst[eind]);

    def save(self, name):
        self.model.save_weights(name)

def preprocess(I):
    I = I[35:195]
    I = I[::2, ::2, 0]
    I[I == 144] = 0
    I[I == 109] = 0
    I[I != 0] = 1
    return I.astype(np.float).ravel()
if __name__ == "__main__":
    env = gym.make("Pong-v0")
    state = env.reset()
    prev_x = None
    score = 0
    episode = 0

    state_size = 80 * 80
    action_size = env.action_space.n
    agent = PGAgent(state_size, action_size)
    
agent.summary();
# Out:
# Using TensorFlow backend.
# [2017-06-14 13:16:34,011] Making new env: Pong-v0
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_1 (Reshape)          (None, 80, 80, 1)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 27, 27, 25)        925
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 27, 27, 5)         4505
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3645)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                72920
# _________________________________________________________________
# dense_2 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_3 (Dense)              (None, 6)                 126
# =================================================================
# Total params: 78,896
# Trainable params: 78,896
# Non-trainable params: 0
# _________________________________________________________________
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:26: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(25, (6, 6), kernel_initializer="he_uniform", activation="relu", padding="same", strides=(3, 3))`
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:28: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(5, (6, 6), kernel_initializer="he_uniform", activation="relu", padding="same", strides=(1, 1))`
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:30: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(20, kernel_initializer="he_uniform", activation="relu")`
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:31: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(20, kernel_initializer="he_uniform", activation="relu")`

# %%
if __name__ == "__main__":
    env = gym.make("Pong-v0")
    state = env.reset()
    prev_x = None
    score = 0
    episode = 0

    state_size = 80 * 80
    action_size = env.action_space.n
    agent = PGAgent(state_size, action_size)
    
agent.summary();
# Out:
# [2017-06-14 13:16:35,065] Making new env: Pong-v0
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_2 (Reshape)          (None, 80, 80, 1)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 27, 27, 25)        925
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 27, 27, 5)         4505
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 3645)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 20)                72920
# _________________________________________________________________
# dense_5 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_6 (Dense)              (None, 6)                 126
# =================================================================
# Total params: 78,896
# Trainable params: 78,896
# Non-trainable params: 0
# _________________________________________________________________
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:26: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(25, (6, 6), kernel_initializer="he_uniform", activation="relu", padding="same", strides=(3, 3))`
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:28: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(5, (6, 6), kernel_initializer="he_uniform", activation="relu", padding="same", strides=(1, 1))`
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:30: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(20, kernel_initializer="he_uniform", activation="relu")`
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:31: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(20, kernel_initializer="he_uniform", activation="relu")`

# %%
if __name__ == "__main__":
    env = gym.make("Pong-v0")
    state = env.reset()
    prev_x = None
    score = 0
    episode = 0

    state_size = 80 * 80
    action_size = env.action_space.n
    agent = PGAgent(state_size, action_size)
#     agent.summary();

AgentName = 'pong_minimal-s4'
AgentFile = 'Models/%s.h5'%AgentName;
LogName = 'Models/%s.log'%AgentName;
# LogFile = open(LogName,'a');
resume = 1;
render = 0;
# agent.readlog(LogName)
# print(agent.episode)
# Out:
# [2017-06-14 13:16:39,989] Making new env: Pong-v0
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:26: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(25, (6, 6), kernel_initializer="he_uniform", activation="relu", padding="same", strides=(3, 3))`
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:28: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(5, (6, 6), kernel_initializer="he_uniform", activation="relu", padding="same", strides=(1, 1))`
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:30: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(20, kernel_initializer="he_uniform", activation="relu")`
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:31: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(20, kernel_initializer="he_uniform", activation="relu")`

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 1)

# %%
if __name__ == "__main__":
    env = gym.make("Pong-v0")
    state = env.reset()
    prev_x = None
    score = 0
    episode = 0

    state_size = 80 * 80
    action_size = env.action_space.n
    agent = PGAgent(state_size, action_size)
#     agent.summary();
    

    if resume:
        agent.load(AgentFile);
        agent.readlog(LogName);
        episode = agent.episode;
    while episode > -1:
        if render:
            env.render()

        cur_x = preprocess(state)
        x = cur_x - prev_x if prev_x is not None else np.zeros(state_size)
        prev_x = cur_x

        action, prob = agent.act(np.expand_dims(x,1).T)
        state, reward, done, info = env.step(action)
        score += reward
        agent.remember(x, action, prob, reward)
        
        if done:
            episode += 1
            rewards = np.vstack(agent.rewards)
            rewards = agent.discount_rewards(rewards)
            grads = np.vstack(agent.gradients);
            pca.fit (grads )
            lvar = pca.explained_variance_ratio_[0];
            all_var = np.sum(np.var(grads,axis = 0));            
            
            agent.train(rewards)
            msg = '%s\t%d\t%s\t%f\t%s\t%f\t%s\t$f' % ('Episode',episode,'Score', score,'largest_variance',lvar,'all_var',all_var);
            print(msg);
            with open(LogName,'a+') as LogFile:
                LogFile.write(msg+'\n');
            
            score = 0
            state = env.reset()
            prev_x = None
            if episode > 1 and episode % 10 == 0:
                agent.save(AgentFile)
# Out:
# [2017-06-14 09:44:52,496] Making new env: Pong-v0
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:26: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(25, (6, 6), kernel_initializer="he_uniform", activation="relu", padding="same", strides=(3, 3))`
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:28: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(5, (6, 6), kernel_initializer="he_uniform", activation="relu", padding="same", strides=(1, 1))`
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:30: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(20, kernel_initializer="he_uniform", activation="relu")`
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:31: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(20, kernel_initializer="he_uniform", activation="relu")`
# Episode	61	Score	-19.000000	largest_variance	0.261778
# Episode	62	Score	-20.000000	largest_variance	0.242455
# Episode	63	Score	-21.000000	largest_variance	0.253545
# Episode	64	Score	-21.000000	largest_variance	0.238833
# Episode	65	Score	-19.000000	largest_variance	0.234565
# Episode	66	Score	-19.000000	largest_variance	0.246555
# Episode	67	Score	-19.000000	largest_variance	0.222083
# Episode	68	Score	-21.000000	largest_variance	0.232081
# Episode	69	Score	-21.000000	largest_variance	0.228370
# Episode	70	Score	-21.000000	largest_variance	0.230340
# Episode	71	Score	-21.000000	largest_variance	0.238805
# Episode	72	Score	-20.000000	largest_variance	0.228974
# Episode	73	Score	-19.000000	largest_variance	0.231396
# Episode	74	Score	-20.000000	largest_variance	0.237261
# Episode	75	Score	-17.000000	largest_variance	0.228584
# Episode	76	Score	-19.000000	largest_variance	0.238803
# Episode	77	Score	-19.000000	largest_variance	0.230578
# Episode	78	Score	-21.000000	largest_variance	0.230351
# Episode	79	Score	-21.000000	largest_variance	0.238275
# Episode	80	Score	-21.000000	largest_variance	0.244075
# Episode	81	Score	-20.000000	largest_variance	0.235019
# Episode	82	Score	-18.000000	largest_variance	0.224898
# Episode	83	Score	-21.000000	largest_variance	0.235387
# Episode	84	Score	-20.000000	largest_variance	0.226208
# Episode	85	Score	-21.000000	largest_variance	0.245734
# Episode	86	Score	-20.000000	largest_variance	0.223139
# Episode	87	Score	-20.000000	largest_variance	0.239850
# Episode	88	Score	-21.000000	largest_variance	0.219895
# Episode	89	Score	-19.000000	largest_variance	0.247757
# Episode	90	Score	-20.000000	largest_variance	0.246425
# Episode	91	Score	-19.000000	largest_variance	0.232647
# Episode	92	Score	-20.000000	largest_variance	0.251973
# Episode	93	Score	-18.000000	largest_variance	0.241429
# Episode	94	Score	-20.000000	largest_variance	0.231301
# Episode	95	Score	-19.000000	largest_variance	0.253329
# Episode	96	Score	-21.000000	largest_variance	0.259038
# Episode	97	Score	-20.000000	largest_variance	0.282131
# Episode	98	Score	-19.000000	largest_variance	0.256455
# Episode	99	Score	-20.000000	largest_variance	0.272072
# Episode	100	Score	-20.000000	largest_variance	0.271908
# Episode	101	Score	-20.000000	largest_variance	0.264253
# Episode	102	Score	-20.000000	largest_variance	0.285795
# Episode	103	Score	-19.000000	largest_variance	0.295661
# Episode	104	Score	-20.000000	largest_variance	0.285902
# Episode	105	Score	-20.000000	largest_variance	0.266473
# Episode	106	Score	-21.000000	largest_variance	0.268242
# Episode	107	Score	-19.000000	largest_variance	0.252468
# Episode	108	Score	-21.000000	largest_variance	0.268936
# Episode	109	Score	-20.000000	largest_variance	0.267454
# Episode	110	Score	-21.000000	largest_variance	0.292312
# Episode	111	Score	-21.000000	largest_variance	0.259647
# Episode	112	Score	-20.000000	largest_variance	0.275057
# Episode	113	Score	-19.000000	largest_variance	0.298817
# Episode	114	Score	-20.000000	largest_variance	0.270906
# Episode	115	Score	-19.000000	largest_variance	0.289349
# Episode	116	Score	-20.000000	largest_variance	0.273004
# Episode	117	Score	-19.000000	largest_variance	0.278870
# Episode	118	Score	-21.000000	largest_variance	0.275922
# Episode	119	Score	-17.000000	largest_variance	0.288320
# Episode	120	Score	-20.000000	largest_variance	0.273450
# Episode	121	Score	-19.000000	largest_variance	0.283689
# Episode	122	Score	-20.000000	largest_variance	0.276233
# Episode	123	Score	-18.000000	largest_variance	0.272696
# Episode	124	Score	-20.000000	largest_variance	0.289128
# Episode	125	Score	-19.000000	largest_variance	0.288734
# Episode	126	Score	-20.000000	largest_variance	0.268958
# Episode	127	Score	-19.000000	largest_variance	0.277420
# Episode	128	Score	-20.000000	largest_variance	0.285363
# Episode	129	Score	-18.000000	largest_variance	0.275656
# Episode	130	Score	-20.000000	largest_variance	0.287199
# Episode	131	Score	-21.000000	largest_variance	0.275907
# Episode	132	Score	-21.000000	largest_variance	0.279863
# Episode	133	Score	-20.000000	largest_variance	0.268387
# Episode	134	Score	-19.000000	largest_variance	0.275753
# Episode	135	Score	-18.000000	largest_variance	0.269552
# Episode	136	Score	-21.000000	largest_variance	0.249880
# Episode	137	Score	-21.000000	largest_variance	0.268803
# Episode	138	Score	-20.000000	largest_variance	0.267553
# Episode	139	Score	-19.000000	largest_variance	0.276267
# Episode	140	Score	-19.000000	largest_variance	0.289859
# Episode	141	Score	-21.000000	largest_variance	0.287785
# Episode	142	Score	-19.000000	largest_variance	0.302654
# Episode	143	Score	-21.000000	largest_variance	0.267812
# Episode	144	Score	-20.000000	largest_variance	0.296174
# Episode	145	Score	-18.000000	largest_variance	0.284265
# Episode	146	Score	-20.000000	largest_variance	0.277712
# Episode	147	Score	-18.000000	largest_variance	0.273297
# Episode	148	Score	-21.000000	largest_variance	0.287784
# Episode	149	Score	-20.000000	largest_variance	0.269010
# Episode	150	Score	-19.000000	largest_variance	0.289499
# Episode	151	Score	-21.000000	largest_variance	0.285100
# Episode	152	Score	-21.000000	largest_variance	0.294726
# Episode	153	Score	-19.000000	largest_variance	0.302712
# Episode	154	Score	-18.000000	largest_variance	0.282399
# Episode	155	Score	-20.000000	largest_variance	0.289472
# Episode	156	Score	-18.000000	largest_variance	0.295345
# Episode	157	Score	-21.000000	largest_variance	0.301483
# Episode	158	Score	-17.000000	largest_variance	0.309527
# Episode	159	Score	-21.000000	largest_variance	0.289609
# Episode	160	Score	-19.000000	largest_variance	0.304002
# Episode	161	Score	-20.000000	largest_variance	0.292034
# Episode	162	Score	-17.000000	largest_variance	0.308767
# Episode	163	Score	-18.000000	largest_variance	0.299943
# Episode	164	Score	-19.000000	largest_variance	0.291216
# Episode	165	Score	-17.000000	largest_variance	0.305275
# Episode	166	Score	-21.000000	largest_variance	0.330232
# Episode	167	Score	-19.000000	largest_variance	0.308984
# Episode	168	Score	-18.000000	largest_variance	0.311269
# Episode	169	Score	-20.000000	largest_variance	0.310278
# Episode	170	Score	-17.000000	largest_variance	0.341493
# Episode	171	Score	-20.000000	largest_variance	0.308620
# Episode	172	Score	-18.000000	largest_variance	0.342558
# Episode	173	Score	-19.000000	largest_variance	0.342044
# Episode	174	Score	-20.000000	largest_variance	0.351212
# Episode	175	Score	-18.000000	largest_variance	0.366224
# Episode	176	Score	-20.000000	largest_variance	0.364483
# Episode	177	Score	-20.000000	largest_variance	0.386873
# Episode	178	Score	-20.000000	largest_variance	0.395271
# Episode	179	Score	-20.000000	largest_variance	0.373077
# Episode	180	Score	-21.000000	largest_variance	0.405245
# Episode	181	Score	-20.000000	largest_variance	0.419333
# Episode	182	Score	-21.000000	largest_variance	0.444075
# Episode	183	Score	-19.000000	largest_variance	0.453654
# Episode	184	Score	-21.000000	largest_variance	0.467687
# Episode	185	Score	-21.000000	largest_variance	0.496770
# Episode	186	Score	-20.000000	largest_variance	0.499806
# Episode	187	Score	-19.000000	largest_variance	0.528361
# Episode	188	Score	-21.000000	largest_variance	0.486334
# Episode	189	Score	-19.000000	largest_variance	0.529021
# Episode	190	Score	-21.000000	largest_variance	0.523039
# Episode	191	Score	-20.000000	largest_variance	0.531129
# Episode	192	Score	-20.000000	largest_variance	0.529887
# Episode	193	Score	-21.000000	largest_variance	0.547437
# Episode	194	Score	-19.000000	largest_variance	0.581258
# Episode	195	Score	-20.000000	largest_variance	0.527616
# Episode	196	Score	-20.000000	largest_variance	0.547391
# Episode	197	Score	-21.000000	largest_variance	0.539021
# Episode	198	Score	-21.000000	largest_variance	0.566224
# Episode	199	Score	-21.000000	largest_variance	0.588995
# Episode	200	Score	-18.000000	largest_variance	0.584801
# Episode	201	Score	-21.000000	largest_variance	0.566857
# Episode	202	Score	-19.000000	largest_variance	0.605812
# Episode	203	Score	-21.000000	largest_variance	0.587001
# Episode	204	Score	-20.000000	largest_variance	0.608181
# Episode	205	Score	-20.000000	largest_variance	0.609967
# Episode	206	Score	-20.000000	largest_variance	0.630469
# Episode	207	Score	-20.000000	largest_variance	0.691759
# Episode	208	Score	-20.000000	largest_variance	0.630319
# Episode	209	Score	-20.000000	largest_variance	0.676609
# Episode	210	Score	-21.000000	largest_variance	0.739951
# Episode	211	Score	-21.000000	largest_variance	0.707959
# Episode	212	Score	-20.000000	largest_variance	0.682099
# Episode	213	Score	-19.000000	largest_variance	0.635688
# Episode	214	Score	-21.000000	largest_variance	0.683310
# Episode	215	Score	-19.000000	largest_variance	0.687360
# Episode	216	Score	-18.000000	largest_variance	0.666447
# Episode	217	Score	-20.000000	largest_variance	0.664706
# Episode	218	Score	-20.000000	largest_variance	0.649473
# Episode	219	Score	-21.000000	largest_variance	0.660967
# Episode	220	Score	-19.000000	largest_variance	0.746360
# Episode	221	Score	-20.000000	largest_variance	0.705542
# Episode	222	Score	-20.000000	largest_variance	0.812150
# Episode	223	Score	-19.000000	largest_variance	0.832550
# Episode	224	Score	-21.000000	largest_variance	0.837230
# Episode	225	Score	-21.000000	largest_variance	0.834964
# Episode	226	Score	-20.000000	largest_variance	0.894461
# Episode	227	Score	-21.000000	largest_variance	0.901992
# Episode	228	Score	-19.000000	largest_variance	0.897962
# Episode	229	Score	-17.000000	largest_variance	0.901429
# Episode	230	Score	-21.000000	largest_variance	0.918897
# Episode	231	Score	-21.000000	largest_variance	0.931008
# Episode	232	Score	-18.000000	largest_variance	0.976228
# Episode	233	Score	-18.000000	largest_variance	0.958489
# Episode	234	Score	-19.000000	largest_variance	0.971769
# Episode	235	Score	-20.000000	largest_variance	0.949381
# Episode	236	Score	-21.000000	largest_variance	0.954849
# Episode	237	Score	-21.000000	largest_variance	0.906211
# Episode	238	Score	-21.000000	largest_variance	0.896569
# Episode	239	Score	-21.000000	largest_variance	0.948980
# Episode	240	Score	-21.000000	largest_variance	0.946949
# Episode	241	Score	-20.000000	largest_variance	0.929864
# Episode	242	Score	-20.000000	largest_variance	0.948211
# Episode	243	Score	-20.000000	largest_variance	0.921758
# Episode	244	Score	-21.000000	largest_variance	0.956274
# Episode	245	Score	-16.000000	largest_variance	0.974252
# Episode	246	Score	-20.000000	largest_variance	0.916538
# Episode	247	Score	-21.000000	largest_variance	0.898039
# Episode	248	Score	-21.000000	largest_variance	0.869452
# Episode	249	Score	-21.000000	largest_variance	0.872446
# Episode	250	Score	-21.000000	largest_variance	0.832129
# Episode	251	Score	-20.000000	largest_variance	0.870063
# Episode	252	Score	-21.000000	largest_variance	0.851464
# Episode	253	Score	-19.000000	largest_variance	0.851101
# Episode	254	Score	-21.000000	largest_variance	0.780347
# Episode	255	Score	-20.000000	largest_variance	0.823477
# Episode	256	Score	-20.000000	largest_variance	0.820349
# Episode	257	Score	-17.000000	largest_variance	0.795775
# Episode	258	Score	-19.000000	largest_variance	0.794471
# Episode	259	Score	-20.000000	largest_variance	0.807670
# Episode	260	Score	-20.000000	largest_variance	0.757140
# Episode	261	Score	-20.000000	largest_variance	0.782849
# Episode	262	Score	-20.000000	largest_variance	0.775296
# Episode	263	Score	-21.000000	largest_variance	0.769662
# Episode	264	Score	-21.000000	largest_variance	0.740059
# Episode	265	Score	-19.000000	largest_variance	0.803503
# Episode	266	Score	-21.000000	largest_variance	0.732759
# Episode	267	Score	-21.000000	largest_variance	0.738285
# Episode	268	Score	-18.000000	largest_variance	0.823274
# Episode	269	Score	-21.000000	largest_variance	0.773401
# Episode	270	Score	-19.000000	largest_variance	0.763353
# Episode	271	Score	-21.000000	largest_variance	0.811912
# Episode	272	Score	-20.000000	largest_variance	0.779249
# Episode	273	Score	-19.000000	largest_variance	0.777819
# Episode	274	Score	-19.000000	largest_variance	0.754309
# Episode	275	Score	-21.000000	largest_variance	0.795139
# Episode	276	Score	-18.000000	largest_variance	0.795565
# Episode	277	Score	-20.000000	largest_variance	0.752262
# Episode	278	Score	-20.000000	largest_variance	0.805262
# Episode	279	Score	-19.000000	largest_variance	0.840765
# Episode	280	Score	-21.000000	largest_variance	0.767944
# Episode	281	Score	-20.000000	largest_variance	0.778410
# Episode	282	Score	-20.000000	largest_variance	0.769092
# Episode	283	Score	-19.000000	largest_variance	0.772313
# Episode	284	Score	-21.000000	largest_variance	0.840743
# Episode	285	Score	-19.000000	largest_variance	0.777842
# Episode	286	Score	-20.000000	largest_variance	0.780118
# Episode	287	Score	-20.000000	largest_variance	0.786737
# Episode	288	Score	-19.000000	largest_variance	0.835765
# Episode	289	Score	-21.000000	largest_variance	0.783813
# Episode	290	Score	-17.000000	largest_variance	0.864597
# Episode	291	Score	-18.000000	largest_variance	0.794070
# Episode	292	Score	-20.000000	largest_variance	0.764113

# %%
pca.explained_variance_ratio_[0]
# Out:
# 0.22254894848773482

# %%
# len(agent.probs)
from sklearn.decomposition import PCA
X = np.vstack(agent.gradients)
pca = PCA(n_components = 1)
pca.fit(X)
print(pca.explained_variance_ratio_)
