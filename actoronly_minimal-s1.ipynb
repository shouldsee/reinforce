# %%
import gym
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Reshape, Flatten
from keras.optimizers import Adam
from keras.layers.convolutional import Convolution2D


class PGAgent:
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.gamma = 0.99
        self.learning_rate = 0.001
        self.states = []
        self.gradients = []
        self.rewards = []
        self.probs = []
        self.model = self._build_model()
        self.summary = self.model.summary;

    def _build_model(self):
        model = Sequential()
        model.add(Reshape((80, 80, 1), input_shape=(self.state_size,)))
        model.add(Convolution2D(5, (6, 6), subsample=(3, 3), border_mode='same',
                                activation='relu', init='he_uniform'))
        model.add(Flatten())
        model.add(Dense(20, activation='relu', init='he_uniform'))
        model.add(Dense(20, activation='relu', init='he_uniform'))
        model.add(Dense(self.action_size, activation='softmax'))
        opt = Adam(lr=self.learning_rate)
        model.compile(loss='categorical_crossentropy', optimizer=opt)
        return model

    def remember(self, state, action, prob, reward):
        y = np.zeros([self.action_size])
        y[action] = 1
        self.gradients.append(np.array(y).astype('float32') - prob)
        self.states.append(state)
        self.rewards.append(reward)

    def act(self, state):
        # state = state.reshape([1, state.shape[0]])
        aprob = self.model.predict(state, batch_size=1).flatten()
        self.probs.append(aprob)
        prob = aprob / np.sum(aprob)
        action = np.random.choice(self.action_size, 1, p=prob)[0]
        return action, prob

    def discount_rewards(self, rewards):
        discounted_rewards = np.zeros_like(rewards)
        running_add = 0
        for t in reversed(range(0, rewards.size)):
            if rewards[t] != 0:
                running_add = 0
            running_add = running_add * self.gamma + rewards[t]
            discounted_rewards[t] = running_add
        return discounted_rewards

    def train(self,rewards):
        gradients = np.vstack(self.gradients)
        # rewards = np.vstack(self.rewards)
        # rewards = self.discount_rewards(rewards)
        rewards = (rewards - np.mean(rewards,keepdims=1)) / np.std(rewards)
        gradients *= rewards
        X = np.squeeze(np.vstack([self.states]))
        Y = self.probs + self.learning_rate * np.squeeze(np.vstack([gradients]))
        self.model.train_on_batch(X, Y)
        self.states, self.probs, self.gradients, self.rewards = [], [], [], []

    def load(self, name):
        self.model.load_weights(name)
        

    def save(self, name):
        self.model.save_weights(name)

def preprocess(I):
    I = I[35:195]
    I = I[::2, ::2, 0]
    I[I == 144] = 0
    I[I == 109] = 0
    I[I != 0] = 1
    return I.astype(np.float).ravel()
if __name__ == "__main__":
    env = gym.make("Pong-v0")
    state = env.reset()
    prev_x = None
    score = 0
    episode = 0

    state_size = 80 * 80
    action_size = env.action_space.n
    agent = PGAgent(state_size, action_size)
    
agent.summary();
# Out:
# Using TensorFlow backend.
# [2017-06-12 12:05:47,361] Making new env: Pong-v0
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_1 (Reshape)          (None, 80, 80, 1)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 27, 27, 5)         185
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3645)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                72920
# _________________________________________________________________
# dense_2 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_3 (Dense)              (None, 6)                 126
# =================================================================
# Total params: 73,651
# Trainable params: 73,651
# Non-trainable params: 0
# _________________________________________________________________
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:26: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(5, (6, 6), kernel_initializer="he_uniform", activation="relu", padding="same", strides=(3, 3))`
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:28: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(20, kernel_initializer="he_uniform", activation="relu")`
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:29: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(20, kernel_initializer="he_uniform", activation="relu")`

# %%
if __name__ == "__main__":
    env = gym.make("Pong-v0")
    state = env.reset()
    prev_x = None
    score = 0
    episode = 0

    state_size = 80 * 80
    action_size = env.action_space.n
    agent = PGAgent(state_size, action_size)
    
agent.summary();
# Out:
# 26

# %%
if __name__ == "__main__":
    env = gym.make("Pong-v0")
    state = env.reset()
    prev_x = None
    score = 0
    episode = 0

    state_size = 80 * 80
    action_size = env.action_space.n
    agent = PGAgent(state_size, action_size)
#     agent.summary();

AgentName = 'pong_minimal-s1'
AgentFile = 'Models/%s.h5'%AgentName;
LogName = 'Models/%s.log'%AgentName;
# LogFile = open(LogName,'a');
resume = 0;
render = 0;

if __name__ == "__main__":
    env = gym.make("Pong-v0")
    state = env.reset()
    prev_x = None
    score = 0
    episode = 0

    state_size = 80 * 80
    action_size = env.action_space.n
    agent = PGAgent(state_size, action_size)
#     agent.summary();
    

    if resume:
        agent.load(AgentFile)
    while episode > -1:
        if render:
            env.render()

        cur_x = preprocess(state)
        x = cur_x - prev_x if prev_x is not None else np.zeros(state_size)
        prev_x = cur_x

        action, prob = agent.act(np.expand_dims(x,1).T)
        state, reward, done, info = env.step(action)
        score += reward
        agent.remember(x, action, prob, reward)
        
        if done:
            episode += 1
            rewards = np.vstack(agent.rewards)
            rewards = agent.discount_rewards(rewards)
            agent.train(rewards)
            msg = '%s\t%d\t%s\t%f' % ('Episode',episode,'Score', score);
            print(msg);
            with open(LogName,'a+') as LogFile:
                LogFile.write(msg+'\n');
            
            score = 0
            state = env.reset()
            prev_x = None
            if episode > 1 and episode % 10 == 0:
                agent.save(AgentFile)
# Out:
# [2017-06-12 12:05:54,616] Making new env: Pong-v0
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:26: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(5, (6, 6), kernel_initializer="he_uniform", activation="relu", padding="same", strides=(3, 3))`
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:28: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(20, kernel_initializer="he_uniform", activation="relu")`
# /home/shouldsee/.local/lib/python2.7/site-packages/ipykernel_launcher.py:29: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(20, kernel_initializer="he_uniform", activation="relu")`
# [2017-06-12 12:05:55,116] Making new env: Pong-v0
# Episode	1	Score	-21.000000
# Episode	2	Score	-19.000000
# Episode	3	Score	-20.000000
# Episode	4	Score	-20.000000
# Episode	5	Score	-21.000000
# Episode	6	Score	-20.000000
# Episode	7	Score	-21.000000
# Episode	8	Score	-20.000000
# Episode	9	Score	-21.000000
# Episode	10	Score	-20.000000
# Episode	11	Score	-21.000000
# Episode	12	Score	-21.000000
# Episode	13	Score	-21.000000
# Episode	14	Score	-20.000000
# Episode	15	Score	-20.000000
# Episode	16	Score	-21.000000
# Episode	17	Score	-21.000000
# Episode	18	Score	-21.000000
# Episode	19	Score	-19.000000
# Episode	20	Score	-21.000000
# Episode	21	Score	-20.000000
# Episode	22	Score	-21.000000
# Episode	23	Score	-21.000000
# Episode	24	Score	-19.000000
# Episode	25	Score	-21.000000
# Episode	26	Score	-21.000000
# Episode	27	Score	-21.000000
# Episode	28	Score	-18.000000
# Episode	29	Score	-20.000000
# Episode	30	Score	-20.000000
# Episode	31	Score	-20.000000
# Episode	32	Score	-21.000000
# Episode	33	Score	-21.000000
# Episode	34	Score	-20.000000
# Episode	35	Score	-21.000000
# Episode	36	Score	-21.000000
# Episode	37	Score	-19.000000
# Episode	38	Score	-19.000000
# Episode	39	Score	-21.000000
# Episode	40	Score	-20.000000
# Episode	41	Score	-20.000000
# Episode	42	Score	-19.000000
# Episode	43	Score	-19.000000
# Episode	44	Score	-19.000000
# Episode	45	Score	-20.000000
# Episode	46	Score	-21.000000
# Episode	47	Score	-20.000000
# Episode	48	Score	-20.000000
# Episode	49	Score	-20.000000
# Episode	50	Score	-21.000000
# Episode	51	Score	-20.000000
# Episode	52	Score	-21.000000
# Episode	53	Score	-19.000000
# Episode	54	Score	-21.000000
# Episode	55	Score	-21.000000
# Episode	56	Score	-21.000000
# Episode	57	Score	-21.000000
# Episode	58	Score	-18.000000
# Episode	59	Score	-20.000000
# Episode	60	Score	-20.000000
# Episode	61	Score	-20.000000
# Episode	62	Score	-19.000000
# Episode	63	Score	-19.000000
# Episode	64	Score	-17.000000
# Episode	65	Score	-20.000000
# Episode	66	Score	-20.000000
# Episode	67	Score	-20.000000
# Episode	68	Score	-17.000000
# Episode	69	Score	-21.000000
# Episode	70	Score	-21.000000
# Episode	71	Score	-21.000000
# Episode	72	Score	-21.000000
# Episode	73	Score	-21.000000
# Episode	74	Score	-20.000000
# Episode	75	Score	-21.000000
# Episode	76	Score	-20.000000
# Episode	77	Score	-19.000000
# Episode	78	Score	-20.000000
# Episode	79	Score	-21.000000
# Episode	80	Score	-21.000000
# Episode	81	Score	-21.000000
# Episode	82	Score	-21.000000
# Episode	83	Score	-21.000000
# Episode	84	Score	-19.000000
# Episode	85	Score	-21.000000
# Episode	86	Score	-21.000000
# Episode	87	Score	-20.000000
# Episode	88	Score	-19.000000
# Episode	89	Score	-19.000000
# Episode	90	Score	-21.000000
# Episode	91	Score	-20.000000
# Episode	92	Score	-21.000000
# Episode	93	Score	-20.000000
# Episode	94	Score	-20.000000
# Episode	95	Score	-19.000000
# Episode	96	Score	-21.000000
# Episode	97	Score	-20.000000
# Episode	98	Score	-21.000000
# Episode	99	Score	-21.000000
# Episode	100	Score	-21.000000
# Episode	101	Score	-21.000000
# Episode	102	Score	-21.000000
# Episode	103	Score	-21.000000
# Episode	104	Score	-18.000000
# Episode	105	Score	-20.000000
# Episode	106	Score	-18.000000
# Episode	107	Score	-20.000000
# Episode	108	Score	-21.000000
# Episode	109	Score	-21.000000
# Episode	110	Score	-21.000000
# Episode	111	Score	-20.000000
# Episode	112	Score	-20.000000
# Episode	113	Score	-20.000000
# Episode	114	Score	-18.000000
# Episode	115	Score	-19.000000
# Episode	116	Score	-20.000000
# Episode	117	Score	-20.000000
# Episode	118	Score	-21.000000
# Episode	119	Score	-21.000000
# Episode	120	Score	-20.000000
# Episode	121	Score	-21.000000
# Episode	122	Score	-19.000000
# Episode	123	Score	-19.000000
# Episode	124	Score	-21.000000
# Episode	125	Score	-18.000000
# Episode	126	Score	-20.000000
# Episode	127	Score	-21.000000
# Episode	128	Score	-20.000000
# Episode	129	Score	-21.000000
# Episode	130	Score	-21.000000
# Episode	131	Score	-21.000000
# Episode	132	Score	-20.000000
# Episode	133	Score	-20.000000
# Episode	134	Score	-19.000000
# Episode	135	Score	-20.000000
# Episode	136	Score	-19.000000
# Episode	137	Score	-20.000000
# Episode	138	Score	-20.000000
# Episode	139	Score	-21.000000
# Episode	140	Score	-20.000000
# Episode	141	Score	-19.000000
# Episode	142	Score	-19.000000
# Episode	143	Score	-21.000000
# Episode	144	Score	-21.000000
# Episode	145	Score	-20.000000
# Episode	146	Score	-21.000000
# Episode	147	Score	-21.000000
# Episode	148	Score	-19.000000
# Episode	149	Score	-20.000000
# Episode	150	Score	-20.000000
# Episode	151	Score	-19.000000
# Episode	152	Score	-20.000000
# Episode	153	Score	-21.000000
# Episode	154	Score	-20.000000
# Episode	155	Score	-20.000000
# Episode	156	Score	-21.000000
# Episode	157	Score	-21.000000
# Episode	158	Score	-20.000000
# Episode	159	Score	-21.000000
# Episode	160	Score	-21.000000
# Episode	161	Score	-20.000000
# Episode	162	Score	-21.000000
# Episode	163	Score	-19.000000
# Episode	164	Score	-20.000000
# Episode	165	Score	-21.000000
# Episode	166	Score	-21.000000
# Episode	167	Score	-19.000000
# Episode	168	Score	-21.000000
# Episode	169	Score	-20.000000
# Episode	170	Score	-19.000000
# Episode	171	Score	-20.000000
# Episode	172	Score	-20.000000
# Episode	173	Score	-20.000000
# Episode	174	Score	-21.000000
# Episode	175	Score	-21.000000
# Episode	176	Score	-20.000000
# Episode	177	Score	-21.000000
# Episode	178	Score	-21.000000
# Episode	179	Score	-21.000000
# Episode	180	Score	-19.000000
# Episode	181	Score	-20.000000
# Episode	182	Score	-19.000000
# Episode	183	Score	-21.000000
# Episode	184	Score	-19.000000
# Episode	185	Score	-20.000000
# Episode	186	Score	-17.000000
# Episode	187	Score	-19.000000
# Episode	188	Score	-21.000000
# Episode	189	Score	-19.000000
# Episode	190	Score	-21.000000
# Episode	191	Score	-20.000000
# Episode	192	Score	-21.000000
# Episode	193	Score	-20.000000
# Episode	194	Score	-21.000000
# Episode	195	Score	-20.000000
# Episode	196	Score	-20.000000
# Episode	197	Score	-20.000000
# Episode	198	Score	-21.000000
# Episode	199	Score	-19.000000
# Episode	200	Score	-20.000000
# Episode	201	Score	-21.000000
# Episode	202	Score	-18.000000
# Episode	203	Score	-20.000000
# Episode	204	Score	-21.000000
# Episode	205	Score	-20.000000
# Episode	206	Score	-21.000000
# Episode	207	Score	-20.000000
# Episode	208	Score	-19.000000
# Episode	209	Score	-20.000000
# Episode	210	Score	-20.000000
# Episode	211	Score	-21.000000
# Episode	212	Score	-19.000000
# Episode	213	Score	-21.000000
# Episode	214	Score	-21.000000
# Episode	215	Score	-19.000000
# Episode	216	Score	-21.000000
# Episode	217	Score	-20.000000
# Episode	218	Score	-20.000000
# Episode	219	Score	-20.000000
# Episode	220	Score	-19.000000
# Episode	221	Score	-19.000000
# Episode	222	Score	-21.000000
# Episode	223	Score	-20.000000
# Episode	224	Score	-21.000000
# Episode	225	Score	-21.000000
# Episode	226	Score	-20.000000
# Episode	227	Score	-21.000000
# Episode	228	Score	-21.000000
# Episode	229	Score	-21.000000
# Episode	230	Score	-18.000000
# Episode	231	Score	-21.000000
# Episode	232	Score	-19.000000
# Episode	233	Score	-20.000000
# Episode	234	Score	-21.000000
# Episode	235	Score	-19.000000
# Episode	236	Score	-21.000000
# Episode	237	Score	-21.000000
# Episode	238	Score	-21.000000
# Episode	239	Score	-20.000000
# Episode	240	Score	-19.000000
# Episode	241	Score	-20.000000
# Episode	242	Score	-20.000000
# Episode	243	Score	-20.000000
# Episode	244	Score	-20.000000
# Episode	245	Score	-21.000000
# Episode	246	Score	-21.000000
# Episode	247	Score	-20.000000
# Episode	248	Score	-20.000000
# Episode	249	Score	-21.000000
# Episode	250	Score	-19.000000
# Episode	251	Score	-20.000000
# Episode	252	Score	-20.000000
# Episode	253	Score	-19.000000
# Episode	254	Score	-20.000000
# Episode	255	Score	-20.000000
# Episode	256	Score	-19.000000
# Episode	257	Score	-21.000000
# Episode	258	Score	-20.000000
# Episode	259	Score	-21.000000
# Episode	260	Score	-20.000000
# Episode	261	Score	-21.000000
# Episode	262	Score	-21.000000
# Episode	263	Score	-21.000000
# Episode	264	Score	-18.000000
# Episode	265	Score	-20.000000
# Episode	266	Score	-21.000000
# Episode	267	Score	-21.000000
# Episode	268	Score	-19.000000
# Episode	269	Score	-21.000000
# Episode	270	Score	-19.000000
# Episode	271	Score	-21.000000
# Episode	272	Score	-20.000000
# Episode	273	Score	-20.000000
# Episode	274	Score	-20.000000
# Episode	275	Score	-20.000000
# Episode	276	Score	-19.000000
# Episode	277	Score	-19.000000
# Episode	278	Score	-19.000000
# Episode	279	Score	-21.000000
# Episode	280	Score	-21.000000
# Episode	281	Score	-21.000000
# Episode	282	Score	-21.000000
# Episode	283	Score	-21.000000
# Episode	284	Score	-19.000000
# Episode	285	Score	-19.000000
# Episode	286	Score	-20.000000
# Episode	287	Score	-20.000000
# Episode	288	Score	-20.000000
# Episode	289	Score	-18.000000
# Episode	290	Score	-21.000000
# Episode	291	Score	-20.000000
# Episode	292	Score	-20.000000
# Episode	293	Score	-21.000000
# Episode	294	Score	-20.000000
# Episode	295	Score	-21.000000
# Episode	296	Score	-21.000000
# Episode	297	Score	-20.000000
# Episode	298	Score	-21.000000
# Episode	299	Score	-19.000000
# Episode	300	Score	-20.000000
# Episode	301	Score	-19.000000
# Episode	302	Score	-20.000000
# Episode	303	Score	-21.000000
# Episode	304	Score	-19.000000
# Episode	305	Score	-20.000000
# Episode	306	Score	-20.000000
# Episode	307	Score	-20.000000
# Episode	308	Score	-21.000000
# Episode	309	Score	-20.000000
# Episode	310	Score	-21.000000
# Episode	311	Score	-20.000000
# Episode	312	Score	-20.000000
# Episode	313	Score	-20.000000
# Episode	314	Score	-20.000000
# Episode	315	Score	-21.000000
# Episode	316	Score	-21.000000
# Episode	317	Score	-20.000000
# Episode	318	Score	-21.000000
# Episode	319	Score	-20.000000
# Episode	320	Score	-20.000000
# Episode	321	Score	-21.000000
# Episode	322	Score	-20.000000
# Episode	323	Score	-20.000000
# Episode	324	Score	-20.000000
# Episode	325	Score	-20.000000
# Episode	326	Score	-21.000000
# Episode	327	Score	-20.000000
# Episode	328	Score	-20.000000
# Episode	329	Score	-20.000000
# Episode	330	Score	-20.000000
# Episode	331	Score	-20.000000
# Episode	332	Score	-20.000000
# Episode	333	Score	-20.000000
# Episode	334	Score	-20.000000
# Episode	335	Score	-21.000000
# Episode	336	Score	-21.000000
# Episode	337	Score	-20.000000
# Episode	338	Score	-20.000000
# Episode	339	Score	-20.000000
# Episode	340	Score	-21.000000
# Episode	341	Score	-21.000000
# Episode	342	Score	-20.000000
# Episode	343	Score	-19.000000
# Episode	344	Score	-21.000000
# Episode	345	Score	-21.000000
# Episode	346	Score	-20.000000
# Episode	347	Score	-20.000000
# Episode	348	Score	-20.000000
# Episode	349	Score	-21.000000
# Episode	350	Score	-21.000000
# Episode	351	Score	-19.000000
# Episode	352	Score	-19.000000
# Episode	353	Score	-20.000000
# Episode	354	Score	-21.000000
# Episode	355	Score	-18.000000
# Episode	356	Score	-21.000000
# Episode	357	Score	-19.000000
# Episode	358	Score	-20.000000
# Episode	359	Score	-21.000000
# Episode	360	Score	-21.000000
# Episode	361	Score	-21.000000
# Episode	362	Score	-21.000000
# Episode	363	Score	-21.000000
# Episode	364	Score	-21.000000
# Episode	365	Score	-17.000000
# Episode	366	Score	-19.000000
# Episode	367	Score	-19.000000
# Episode	368	Score	-21.000000
# Episode	369	Score	-21.000000
# Episode	370	Score	-20.000000
# Episode	371	Score	-21.000000
# Episode	372	Score	-19.000000
# Episode	373	Score	-20.000000
# Episode	374	Score	-21.000000
# Episode	375	Score	-21.000000
# Episode	376	Score	-20.000000
# Episode	377	Score	-21.000000
# Episode	378	Score	-20.000000
# Episode	379	Score	-21.000000
# Episode	380	Score	-21.000000
# Episode	381	Score	-20.000000
# Episode	382	Score	-21.000000
# Episode	383	Score	-21.000000
# Episode	384	Score	-20.000000
# Episode	385	Score	-20.000000
# Episode	386	Score	-20.000000
# Episode	387	Score	-20.000000
# Episode	388	Score	-21.000000
# Episode	389	Score	-20.000000
# Episode	390	Score	-20.000000
# Episode	391	Score	-20.000000
# Episode	392	Score	-21.000000
# Episode	393	Score	-21.000000
# Episode	394	Score	-21.000000
# Episode	395	Score	-20.000000
# Episode	396	Score	-20.000000
# Episode	397	Score	-20.000000
# Episode	398	Score	-20.000000
# Episode	399	Score	-21.000000
# Episode	400	Score	-20.000000
# Episode	401	Score	-20.000000
# Episode	402	Score	-21.000000
# Episode	403	Score	-19.000000
# Episode	404	Score	-19.000000
# Episode	405	Score	-19.000000
# Episode	406	Score	-21.000000
# Episode	407	Score	-21.000000
# Episode	408	Score	-20.000000
# Episode	409	Score	-21.000000
# Episode	410	Score	-21.000000
# Episode	411	Score	-19.000000
# Episode	412	Score	-20.000000
# Episode	413	Score	-21.000000
# Episode	414	Score	-19.000000
# Episode	415	Score	-20.000000
# Episode	416	Score	-20.000000
# Episode	417	Score	-20.000000
# Episode	418	Score	-20.000000
# Episode	419	Score	-20.000000
# Episode	420	Score	-20.000000
# Episode	421	Score	-20.000000
# Episode	422	Score	-21.000000
# Episode	423	Score	-21.000000
# Episode	424	Score	-20.000000
# Episode	425	Score	-20.000000
# Episode	426	Score	-20.000000
# Episode	427	Score	-21.000000
# Episode	428	Score	-20.000000
# Episode	429	Score	-21.000000
# Episode	430	Score	-21.000000
# Episode	431	Score	-21.000000
# Episode	432	Score	-20.000000
# Episode	433	Score	-21.000000
# Episode	434	Score	-21.000000
# Episode	435	Score	-21.000000
# Episode	436	Score	-20.000000
# Episode	437	Score	-21.000000
# Episode	438	Score	-20.000000
# Episode	439	Score	-20.000000
# Episode	440	Score	-20.000000
# Episode	441	Score	-21.000000
# Episode	442	Score	-21.000000
# Episode	443	Score	-21.000000
# Episode	444	Score	-21.000000
# Episode	445	Score	-20.000000
# Episode	446	Score	-20.000000
# Episode	447	Score	-21.000000
# Episode	448	Score	-21.000000
# Episode	449	Score	-20.000000
# Episode	450	Score	-21.000000
# Episode	451	Score	-20.000000
# Episode	452	Score	-20.000000
# Episode	453	Score	-21.000000
# Episode	454	Score	-21.000000
# Episode	455	Score	-21.000000
# Episode	456	Score	-20.000000
# Episode	457	Score	-21.000000
# Episode	458	Score	-20.000000
# Episode	459	Score	-20.000000
# Episode	460	Score	-20.000000
# Episode	461	Score	-21.000000
# Episode	462	Score	-21.000000
# Episode	463	Score	-20.000000
# Episode	464	Score	-21.000000
# Episode	465	Score	-21.000000
# Episode	466	Score	-20.000000
# Episode	467	Score	-20.000000
# Episode	468	Score	-21.000000
# Episode	469	Score	-21.000000
# Episode	470	Score	-21.000000
# Episode	471	Score	-21.000000
# Episode	472	Score	-20.000000
# Episode	473	Score	-21.000000
# Episode	474	Score	-21.000000
# Episode	475	Score	-21.000000
# Episode	476	Score	-21.000000
# Episode	477	Score	-21.000000
# Episode	478	Score	-21.000000
# Episode	479	Score	-21.000000
# Episode	480	Score	-20.000000
# Episode	481	Score	-20.000000
# Episode	482	Score	-20.000000
# Episode	483	Score	-21.000000
# Episode	484	Score	-21.000000
# Episode	485	Score	-21.000000
# Episode	486	Score	-20.000000
# Episode	487	Score	-20.000000
# Episode	488	Score	-20.000000
# Episode	489	Score	-21.000000
# Episode	490	Score	-21.000000
# Episode	491	Score	-21.000000
# Episode	492	Score	-21.000000
# Episode	493	Score	-20.000000
# Episode	494	Score	-20.000000
# Episode	495	Score	-20.000000
# Episode	496	Score	-21.000000
# Episode	497	Score	-21.000000
# Episode	498	Score	-20.000000
# Episode	499	Score	-21.000000
# Episode	500	Score	-21.000000
# Episode	501	Score	-21.000000
# Episode	502	Score	-21.000000
# Episode	503	Score	-20.000000
# Episode	504	Score	-21.000000
# Episode	505	Score	-20.000000
# Episode	506	Score	-21.000000
# Episode	507	Score	-20.000000
# Episode	508	Score	-20.000000
# Episode	509	Score	-20.000000
# Episode	510	Score	-21.000000
# Episode	511	Score	-21.000000
# Episode	512	Score	-20.000000
# Episode	513	Score	-21.000000
# Episode	514	Score	-20.000000
# Episode	515	Score	-21.000000
# Episode	516	Score	-21.000000
# Episode	517	Score	-21.000000
# Episode	518	Score	-21.000000
# Episode	519	Score	-21.000000
# Episode	520	Score	-21.000000
# Episode	521	Score	-21.000000
# Episode	522	Score	-20.000000
# Episode	523	Score	-20.000000
# Episode	524	Score	-21.000000
# Episode	525	Score	-20.000000
# Episode	526	Score	-21.000000
# Episode	527	Score	-21.000000
# Episode	528	Score	-20.000000
# Episode	529	Score	-20.000000
# Episode	530	Score	-20.000000
# Episode	531	Score	-20.000000
# Episode	532	Score	-20.000000
# Episode	533	Score	-19.000000
# Episode	534	Score	-20.000000
# Episode	535	Score	-21.000000
# Episode	536	Score	-20.000000
# Episode	537	Score	-21.000000
# Episode	538	Score	-20.000000
# Episode	539	Score	-20.000000
# Episode	540	Score	-21.000000
# Episode	541	Score	-20.000000
# Episode	542	Score	-20.000000
# Episode	543	Score	-21.000000
# Episode	544	Score	-21.000000
# Episode	545	Score	-21.000000
# Episode	546	Score	-21.000000
# Episode	547	Score	-21.000000
# Episode	548	Score	-20.000000
# Episode	549	Score	-21.000000
# Episode	550	Score	-21.000000
# Episode	551	Score	-20.000000
# Episode	552	Score	-20.000000
# Episode	553	Score	-21.000000
# Episode	554	Score	-20.000000
# Episode	555	Score	-20.000000
# Episode	556	Score	-20.000000
# Episode	557	Score	-21.000000
# Episode	558	Score	-21.000000
# Episode	559	Score	-20.000000
# Episode	560	Score	-21.000000
# Episode	561	Score	-20.000000
# Episode	562	Score	-20.000000
# Episode	563	Score	-20.000000
# Episode	564	Score	-21.000000
# Episode	565	Score	-20.000000
# Episode	566	Score	-20.000000
# Episode	567	Score	-21.000000
# Episode	568	Score	-20.000000
# Episode	569	Score	-20.000000
# Episode	570	Score	-21.000000
# Episode	571	Score	-20.000000
# Episode	572	Score	-19.000000
# Episode	573	Score	-21.000000
# Episode	574	Score	-21.000000
# Episode	575	Score	-20.000000
# Episode	576	Score	-20.000000
# Episode	577	Score	-20.000000
# Episode	578	Score	-21.000000
# Episode	579	Score	-21.000000
# Episode	580	Score	-21.000000
# Episode	581	Score	-21.000000
# Episode	582	Score	-20.000000
# Episode	583	Score	-20.000000
# Episode	584	Score	-20.000000
# Episode	585	Score	-21.000000
# Episode	586	Score	-19.000000
# Episode	587	Score	-21.000000
# Episode	588	Score	-21.000000
# Episode	589	Score	-21.000000
# Episode	590	Score	-21.000000
# Episode	591	Score	-20.000000
# Episode	592	Score	-21.000000
# Episode	593	Score	-21.000000
# Episode	594	Score	-21.000000
# Episode	595	Score	-20.000000
# Episode	596	Score	-20.000000
# Episode	597	Score	-21.000000
# Episode	598	Score	-21.000000
# Episode	599	Score	-21.000000
# Episode	600	Score	-20.000000
# Episode	601	Score	-21.000000
# Episode	602	Score	-21.000000
# Episode	603	Score	-20.000000
# Episode	604	Score	-19.000000
# Episode	605	Score	-21.000000
# Episode	606	Score	-21.000000
# Episode	607	Score	-18.000000
# Episode	608	Score	-19.000000
# Episode	609	Score	-19.000000
# Episode	610	Score	-19.000000
# Episode	611	Score	-19.000000
# Episode	612	Score	-20.000000
# Episode	613	Score	-21.000000
# Episode	614	Score	-20.000000
# Episode	615	Score	-19.000000
# Episode	616	Score	-20.000000
# Episode	617	Score	-20.000000
# Episode	618	Score	-17.000000
# Episode	619	Score	-20.000000
# Episode	620	Score	-21.000000
# Episode	621	Score	-19.000000
# Episode	622	Score	-18.000000
# Episode	623	Score	-21.000000
# Episode	624	Score	-19.000000
# Episode	625	Score	-20.000000
# Episode	626	Score	-21.000000
# Episode	627	Score	-20.000000
# Episode	628	Score	-19.000000
# Episode	629	Score	-20.000000
# Episode	630	Score	-19.000000
# Episode	631	Score	-21.000000
# Episode	632	Score	-20.000000
# Episode	633	Score	-20.000000
# Episode	634	Score	-20.000000
# Episode	635	Score	-21.000000
# Episode	636	Score	-21.000000
# Episode	637	Score	-20.000000
# Episode	638	Score	-21.000000
# Episode	639	Score	-21.000000
# Episode	640	Score	-21.000000
# Episode	641	Score	-21.000000
# Episode	642	Score	-20.000000
# Episode	643	Score	-20.000000
# Episode	644	Score	-21.000000
# Episode	645	Score	-20.000000
# Episode	646	Score	-21.000000
# Episode	647	Score	-20.000000
# Episode	648	Score	-21.000000
# Episode	649	Score	-21.000000
# Episode	650	Score	-20.000000
# Episode	651	Score	-21.000000
# Episode	652	Score	-21.000000
# Episode	653	Score	-21.000000
# Episode	654	Score	-21.000000
# Episode	655	Score	-20.000000
# Episode	656	Score	-20.000000
# Episode	657	Score	-20.000000
# Episode	658	Score	-21.000000
# Episode	659	Score	-21.000000
# Episode	660	Score	-21.000000
# Episode	661	Score	-20.000000
# Episode	662	Score	-21.000000
# Episode	663	Score	-19.000000
# Episode	664	Score	-20.000000
# Episode	665	Score	-21.000000
# Episode	666	Score	-21.000000
# Episode	667	Score	-21.000000
# Episode	668	Score	-21.000000
# Episode	669	Score	-20.000000
# Episode	670	Score	-21.000000
# Episode	671	Score	-20.000000
# Episode	672	Score	-21.000000
# Episode	673	Score	-20.000000
# Episode	674	Score	-20.000000
# Episode	675	Score	-19.000000
# Episode	676	Score	-21.000000
# Episode	677	Score	-21.000000
# Episode	678	Score	-21.000000
# Episode	679	Score	-19.000000
# Episode	680	Score	-21.000000
# Episode	681	Score	-21.000000
# Episode	682	Score	-21.000000
# Episode	683	Score	-21.000000
# Episode	684	Score	-19.000000
# Episode	685	Score	-21.000000
# Episode	686	Score	-21.000000
# Episode	687	Score	-17.000000
# Episode	688	Score	-19.000000
# Episode	689	Score	-21.000000
# Episode	690	Score	-21.000000
# Episode	691	Score	-21.000000
# Episode	692	Score	-21.000000
# Episode	693	Score	-20.000000
# Episode	694	Score	-20.000000
# Episode	695	Score	-21.000000
# Episode	696	Score	-19.000000
# Episode	697	Score	-21.000000
# Episode	698	Score	-21.000000
# Episode	699	Score	-21.000000
# Episode	700	Score	-21.000000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-9988342fa741> in <module>()
#      41         prev_x = cur_x
#      42
# ---> 43         action, prob = agent.act(np.expand_dims(x,1).T)
#      44         state, reward, done, info = env.step(action)
#      45         score += reward
#
# <ipython-input-1-7e34a0dbe129> in act(self, state)
#      42     def act(self, state):
#      43         # state = state.reshape([1, state.shape[0]])
# ---> 44         aprob = self.model.predict(state, batch_size=1).flatten()
#      45         self.probs.append(aprob)
#      46         prob = aprob / np.sum(aprob)
#
# /home/shouldsee/.local/lib/python2.7/site-packages/keras/models.pyc in predict(self, x, batch_size, verbose)
#     900         if self.model is None:
#     901             self.build()
# --> 902         return self.model.predict(x, batch_size=batch_size, verbose=verbose)
#     903
#     904     def predict_on_batch(self, x):
#
# /home/shouldsee/.local/lib/python2.7/site-packages/keras/engine/training.pyc in predict(self, x, batch_size, verbose)
#    1583         f = self.predict_function
#    1584         return self._predict_loop(f, ins,
# -> 1585                                   batch_size=batch_size, verbose=verbose)
#    1586
#    1587     def train_on_batch(self, x, y,
#
# /home/shouldsee/.local/lib/python2.7/site-packages/keras/engine/training.pyc in _predict_loop(self, f, ins, batch_size, verbose)
#    1210                 ins_batch = _slice_arrays(ins, batch_ids)
#    1211
# -> 1212             batch_outs = f(ins_batch)
#    1213             if not isinstance(batch_outs, list):
#    1214                 batch_outs = [batch_outs]
#
# /home/shouldsee/.local/lib/python2.7/site-packages/keras/backend/tensorflow_backend.pyc in __call__(self, inputs)
#    2227         session = get_session()
#    2228         updated = session.run(self.outputs + [self.updates_op],
# -> 2229                               feed_dict=feed_dict)
#    2230         return updated[:len(self.outputs)]
#    2231
#
# /home/shouldsee/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     776     try:
#     777       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 778                          run_metadata_ptr)
#     779       if run_metadata:
#     780         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/shouldsee/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     980     if final_fetches or final_targets:
#     981       results = self._do_run(handle, final_targets, final_fetches,
# --> 982                              feed_dict_string, options, run_metadata)
#     983     else:
#     984       results = []
#
# /home/shouldsee/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1030     if handle is None:
#    1031       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1032                            target_list, options, run_metadata)
#    1033     else:
#    1034       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/shouldsee/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1037   def _do_call(self, fn, *args):
#    1038     try:
# -> 1039       return fn(*args)
#    1040     except errors.OpError as e:
#    1041       message = compat.as_text(e.message)
#
# /home/shouldsee/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1019         return tf_session.TF_Run(session, options,
#    1020                                  feed_dict, fetch_list, target_list,
# -> 1021                                  status, run_metadata)
#    1022
#    1023     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
print >> LogFile, 'Hi'

# %%
LogFile = open('Models/%s.log'%AgentName,'a')
LogFile.write('Hi')
